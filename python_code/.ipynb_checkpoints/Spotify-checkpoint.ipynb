# %%
import matplotlib.pyplot as plt
import pandas as pd
import requests
import spotipy
import scipy.stats as st
from scipy.optimize import curve_fit
import numpy as np
from datetime import date
from config import mongo_uri

#from config import credentials
# Import API key
#from config import api_key
#from config import token

# %%
user_id='me'
kind='artists' #tracks
limit=50
token='BQCijNsK5HHAISWGn6iRiWv8_rUdCHEiVl4Z56WZbxF0UMePxSqwu8-HMzGU8h8sclqZsGzi-EKjQqvysTujfhKTpGxkHIaP5-Wrkjz6tvTrCAxSeJwMWi7BFlujGZFSbzNiv0sKPOkDjUzV65u7p7oSYjJAN1ij_YmeDfVSuK1vhq8M0bpC2sjd4_HQ2julUV9119cZRcGN0_HJZiJ9suRr_E0p7YMQT3Xg5zp1usvppy3UudlicTvb5wENvB2M6kfm7TCEzV7ukYlP'

params={'time_range':'long_term','limit' : limit}
headers={"Accept": "application/json","Content-Type": "application/json","Authorization": 
         (f"Bearer {token}")}

#medium_term, short term

base_url=f'https://api.spotify.com/v1/{user_id}/top/{kind}?'#{api_key}'    #{timeframe}/{api_key}

# %%
#https://api.spotify.com/v1/me/top/artists?time_range=long_term&limit=20

# %%
# user_data = requests.get(base_url,headers = headers,params=params).json()
# user_data['items'][0]['id']

# %%
SPOTIFY_AUTH_URL = "https://accounts.spotify.com/authorize"
SPOTIFY_TOKEN_URL = "https://accounts.spotify.com/api/token"
SPOTIFY_API_BASE_URL = "https://api.spotify.com"
API_VERSION = "v1"
SPOTIFY_API_URL = "{}/{}".format(SPOTIFY_API_BASE_URL, API_VERSION)

user_data = {}
user_url = "{}/me".format(SPOTIFY_API_URL)
user = requests.get(user_url, headers=headers).json()
name = user['display_name']
id = user['id']
limit=50


top_50_url = "{}/me/top/artists?time_range=long_term&limit=50".format(SPOTIFY_API_URL)
top_50 = requests.get(top_50_url, headers=headers).json()

top_50_url_tracks = "{}/me/top/tracks?time_range=long_term&limit=50".format(SPOTIFY_API_URL)
top_50_artists = requests.get(top_50_url_tracks, headers=headers).json()



tracks = []
track_info = {}


for i in range(50):
    track_info['track'] = top_50_artists['items'][i]['name']
    track_info['artist'] = top_50_artists['items'][i]['album']['artists'][0]['name']
    track_info['album'] = top_50_artists['items'][i]['album']['name']
    track_info['id'] = top_50_artists['items'][i]['id']
    
    #get track analysis
    track_url = "{}/audio-features?ids={}".format(SPOTIFY_API_URL,tracks[i]['id'])
    track_analysis_data = requests.get(track_url, headers=headers).json()
    
    track_info['audio_features'] = track_analysis_data['audio_features']
    
    
    
    tracks.append(track_info)
    track_info = {}

# track_name = []
# track_artist = []
# track_album = []
#track_
# for i in range(50):
#     artists.append(top_50['items'][i]['name'])
#     genres.append(top_50['items'][i]['genres'])
#     popularity.append(top_50['items'][i]['popularity'])
#     artist_id.append(top_50['items'][i]['id'])


artists=[]
genres=[]
artist_id = []
popularity=[]
for i in range(50):
    artists.append(top_50['items'][i]['name'])
    genres.append(top_50['items'][i]['genres'])
    popularity.append(top_50['items'][i]['popularity'])
    artist_id.append(top_50['items'][i]['id'])

top_artists=[]
artist_info = {}
for i in range(50):
    artist_info['artist'] = artists[i]
    artist_info['id'] = artist_id[i]
    artist_info['popularity'] = popularity[i]
    artist_info['genres'] = genres[i]
    top_artists.append(artist_info)
    artist_info={}

#mean_pop=popularity.mean()
genres_complete = []
for i in genres:
    for a in i:
        genres_complete.append(a)

user_data['date_updated'] = date.today().strftime("%m/%d/%Y")
user_data['name'] = name
user_data['id'] = id
user_data['top_50_artists'] = top_artists
user_data['top_50_tracks']= tracks
user_data['genres'] = genres_complete

# %%
user_data
#tracks
# Out:
# {'date_updated': '10/11/2020',
#  'name': 'Henry Byoun',
#  'id': '1275175786',
#  'top_50_artists': [{'artist': 'IU',
#    'id': '3HqSLMAZ3g3d5poNaI7GOU',
#    'popularity': 77,
#    'genres': ['k-pop']},
#   {'artist': 'RADWIMPS',
#    'id': '1EowJ1WwkMzkCkRomFhui7',
#    'popularity': 75,
#    'genres': ['j-pop', 'j-rock', 'japanese emo', 'visual kei']},
#   {'artist': 'TWICE',
#    'id': '7n2Ycct7Beij7Dj7meI4X0',
#    'popularity': 82,
#    'genres': ['k-pop', 'k-pop girl group']},
#   {'artist': 'EGOIST',
#    'id': '0k7JZhYS35IewiKNHW7KMj',
#    'popularity': 58,
#    'genres': ['anime', 'anime rock', 'anime score', 'otacore']},
#   {'artist': 'GFRIEND',
#    'id': '0qlWcS66ohOIi0M8JZwPft',
#    'popularity': 67,
#    'genres': ['k-pop', 'k-pop girl group']},
#   {'artist': 'All Time Low',
#    'id': '46gyXjRIvN1NL1eCB8GBxo',
#    'popularity': 75,
#    'genres': ['modern rock', 'pop punk', 'post-teen pop']},
#   {'artist': 'The Japanese House',
#    'id': '3IunaFjvNKj98JW89JYv9u',
#    'popularity': 67,
#    'genres': ['art pop',
#     'electropop',
#     'indie pop',
#     'indie poptimism',
#     'indie r&b',
#     'indietronica',
#     'modern dream pop',
#     'vapor soul']},
#   {'artist': 'daigoro789',
#    'id': '6dOnTTVTbQlFWF6yfD4Vw5',
#    'popularity': 62,
#    'genres': ['japanese instrumental', 'otacore', 'scorecore']},
#   {'artist': 'Twenty One Pilots',
#    'id': '3YQKmKGau1PzlVlkL1iodx',
#    'popularity': 86,
#    'genres': ['modern rock', 'rock']},
#   {'artist': 'Grimes',
#    'id': '053q0ukIDRgzwTr4vNSwab',
#    'popularity': 73,
#    'genres': ['art pop',
#     'canadian electropop',
#     'chillwave',
#     'dance pop',
#     'electropop',
#     'escape room',
#     'grave wave',
#     'indie pop',
#     'indietronica',
#     'metropopolis',
#     'new rave']},
#   {'artist': 'The Naked And Famous',
#    'id': '0oeUpvxWsC8bWS6SnpU8b9',
#    'popularity': 63,
#    'genres': ['alternative dance',
#     'auckland indie',
#     'electropop',
#     'indie pop',
#     'indie poptimism',
#     'indie rock',
#     'indietronica',
#     'kiwi rock',
#     'metropopolis',
#     'modern rock',
#     'shimmer pop']},
#   {'artist': 'CHVRCHES',
#    'id': '3CjlHNtplJyTf9npxaPl5w',
#    'popularity': 72,
#    'genres': ['electropop',
#     'indie pop',
#     'indie poptimism',
#     'metropopolis',
#     'neo-synthpop',
#     'shimmer pop']},
#   {'artist': 'Yerin Baek',
#    'id': '6dhfy4ByARPJdPtMyrUYJK',
#    'popularity': 63,
#    'genres': ['k-indie', 'k-pop', 'korean pop']},
#   {'artist': 'LiSA',
#    'id': '0blbVefuxOGltDBa00dspv',
#    'popularity': 74,
#    'genres': ['anime rock', 'j-pixie', 'otacore']},
#   {'artist': 'MUNA',
#    'id': '6xdRb2GypJ7DqnWAI2mHGn',
#    'popularity': 61,
#    'genres': ['art pop',
#     'dance pop',
#     'electropop',
#     'indie electropop',
#     'indie pop',
#     'indie poptimism',
#     'la pop',
#     'metropopolis',
#     'pop',
#     'vapor soul']},
#   {'artist': 'Bright Eyes',
#    'id': '5o206eFLx38glA2bb4zqIU',
#    'popularity': 65,
#    'genres': ['anti-folk',
#     'indie folk',
#     'indie pop',
#     'indie rock',
#     'melancholia',
#     'omaha indie',
#     'stomp and holler']},
#   {'artist': 'Manchester Orchestra',
#    'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#    'popularity': 62,
#    'genres': ['dreamo', 'indie rock', 'modern rock']},
#   {'artist': 'Chairlift',
#    'id': '7hAolICGSgXJuM6DUpK5rp',
#    'popularity': 48,
#    'genres': ['alternative dance',
#     'art pop',
#     'brooklyn indie',
#     'chillwave',
#     'electropop',
#     'escape room',
#     'indie pop',
#     'metropopolis',
#     'neo-synthpop',
#     'shimmer pop']},
#   {'artist': 'Taking Back Sunday',
#    'id': '24XtlMhEMNdi822vi0MhY1',
#    'popularity': 65,
#    'genres': ['emo', 'pop punk']},
#   {'artist': 'Kero Kero Bonito',
#    'id': '6OqhFYFJDnBBHas02HopPT',
#    'popularity': 63,
#    'genres': ['escape room', 'hyperpop', 'japanese electropop']},
#   {'artist': 'Metric',
#    'id': '1rCIEwPp5OnXW0ornlSsRl',
#    'popularity': 63,
#    'genres': ['alternative dance',
#     'canadian indie',
#     'canadian rock',
#     'dance-punk',
#     'electropop',
#     'indie pop',
#     'indie rock',
#     'indietronica',
#     'metropopolis',
#     'modern rock',
#     'neo-synthpop',
#     'new rave',
#     'shimmer pop']},
#   {'artist': 'Mr Twin Sister',
#    'id': '5ltJZgIW3OkY5WvuzX5MYz',
#    'popularity': 50,
#    'genres': ['art pop', 'chillwave']},
#   {'artist': 'Relient K',
#    'id': '3nJWBJvK7uGvfp4iZh9CkN',
#    'popularity': 61,
#    'genres': ['canadian ccm',
#     'christian alternative rock',
#     'christian music',
#     'christian punk',
#     'christian rock',
#     'emo',
#     'neo mellow',
#     'pop punk',
#     'pop rock']},
#   {'artist': 'Purity Ring',
#    'id': '1TtJ8j22Roc24e2Jx3OcU4',
#    'popularity': 61,
#    'genres': ['art pop',
#     'canadian electropop',
#     'chillwave',
#     'edmonton indie',
#     'electropop',
#     'grave wave',
#     'indietronica',
#     'metropopolis',
#     'shimmer pop',
#     'vapor soul']},
#   {'artist': 'Mayday Parade',
#    'id': '3WfJ1OtrWI7RViX9DMyEGy',
#    'popularity': 68,
#    'genres': ['emo', 'neon pop punk', 'pop emo', 'pop punk']},
#   {'artist': 'Kanye West',
#    'id': '5K4W6rqBFWDnAN6FQUkS6x',
#    'popularity': 91,
#    'genres': ['chicago rap', 'rap']},
#   {'artist': 'The Used',
#    'id': '55VydwMyCuGcavwPuhutPL',
#    'popularity': 69,
#    'genres': ['post-hardcore', 'screamo']},
#   {'artist': 'Blood Orange',
#    'id': '6LEeAFiJF8OuPx747e1wxR',
#    'popularity': 68,
#    'genres': ['alternative r&b',
#     'art pop',
#     'chillwave',
#     'electropop',
#     'escape room',
#     'indie soul',
#     'metropopolis']},
#   {'artist': 'Wolf Alice',
#    'id': '3btzEQD6sugImIHPMRgkwV',
#    'popularity': 60,
#    'genres': ['indie rock', 'modern alternative rock', 'modern rock', 'rock']},
#   {'artist': 'BOL4',
#    'id': '4k5fFEYgkWYrYvtOK3zVBl',
#    'popularity': 69,
#    'genres': ['k-pop', 'korean pop']},
#   {'artist': 'Something Corporate',
#    'id': '71h7GTahhKcSkQ1ayhTvOD',
#    'popularity': 50,
#    'genres': ['emo',
#     'neon pop punk',
#     'piano rock',
#     'pop emo',
#     'pop punk',
#     'pop rock']},
#   {'artist': 'SURAN',
#    'id': '1mORehSVEd7lcaT2d7Sl2K',
#    'popularity': 61,
#    'genres': ['k-indie', 'k-pop', 'korean r&b']},
#   {'artist': 'Phantogram',
#    'id': '1l9d7B8W0IHy3LqWsxP2SH',
#    'popularity': 63,
#    'genres': ['alternative dance',
#     'chillwave',
#     'electropop',
#     'indie pop',
#     'indie rock',
#     'indietronica',
#     'metropopolis',
#     'modern rock',
#     'shimmer pop',
#     'vapor soul']},
#   {'artist': '藤澤慶昌',
#    'id': '1sNFJ2IaKm03L1qQs2wZw6',
#    'popularity': 37,
#    'genres': ['anime score']},
#   {'artist': 'Bon Iver',
#    'id': '4LEiUm1SRbFMgfqnQTwUbQ',
#    'popularity': 81,
#    'genres': ['eau claire indie', 'indie folk', 'melancholia']},
#   {'artist': 'Tegan and Sara',
#    'id': '5e1BZulIiYWPRm8yogwUYH',
#    'popularity': 63,
#    'genres': ['canadian indie',
#     'indie pop',
#     'indie poptimism',
#     'indie rock',
#     'lilith',
#     'metropopolis',
#     'permanent wave',
#     'pop rock']},
#   {'artist': 'Broods',
#    'id': '5r5Va4lVQ1zjEfbJSrmCsS',
#    'popularity': 63,
#    'genres': ['art pop',
#     'auckland indie',
#     'electropop',
#     'etherpop',
#     'indie electropop',
#     'indie pop',
#     'indie poptimism',
#     'indietronica',
#     'metropopolis',
#     'nz pop',
#     'pop',
#     'shimmer pop',
#     'tropical house',
#     'vapor soul']},
#   {'artist': 'The xx',
#    'id': '3iOvXCl6edW5Um0fXEBRXy',
#    'popularity': 72,
#    'genres': ['downtempo', 'dream pop', 'indietronica']},
#   {'artist': 'Kishi Bashi',
#    'id': '3LVPGE5jPPwtbGslx07YR0',
#    'popularity': 55,
#    'genres': ['indie pop',
#     'metropopolis',
#     'shimmer pop',
#     'stomp and holler',
#     'stomp and whittle']},
#   {'artist': 'BANKS',
#    'id': '2xe8IXgCTpwHE3eA9hTs4n',
#    'popularity': 67,
#    'genres': ['alternative r&b',
#     'art pop',
#     'dance pop',
#     'electropop',
#     'indie poptimism',
#     'indie r&b',
#     'pop',
#     'vapor soul']},
#   {'artist': 'Kensuke Ushio',
#    'id': '4L0gz16xuM1as1OgYzh1SR',
#    'popularity': 61,
#    'genres': ['anime score', 'japanese soundtrack', 'otacore']},
#   {'artist': 'Bastille',
#    'id': '7EQ0qTo7fWT7DPxmxtSYEc',
#    'popularity': 81,
#    'genres': ['metropopolis', 'modern rock', 'pop', 'pop rock']},
#   {'artist': 'Fickle Friends',
#    'id': '1nhSLEYdoBHG6cJ8NDwoF1',
#    'popularity': 51,
#    'genres': ['gauze pop',
#     'hopebeat',
#     'indie electropop',
#     'indie pop',
#     'indie poptimism',
#     'shimmer pop',
#     'uk pop',
#     'vapor soul']},
#   {'artist': 'Sylvan Esso',
#    'id': '39vA9YljbnOApXKniLWBZv',
#    'popularity': 69,
#    'genres': ['art pop',
#     'electropop',
#     'etherpop',
#     'indie folk',
#     'indie pop',
#     'indie rock']},
#   {'artist': 'SILENT SIREN',
#    'id': '11FVEsg4m3QWzNfaK7vykQ',
#    'popularity': 50,
#    'genres': ['alt-idol',
#     'anime',
#     'anime rock',
#     'heavy alternative',
#     'idol rock',
#     'j-idol',
#     'j-pixie',
#     'j-pop']},
#   {'artist': 'Wet',
#    'id': '2i9uaNzfUtuApAjEf1omV8',
#    'popularity': 59,
#    'genres': ['brooklyn indie',
#     'electropop',
#     'indie electropop',
#     'indie pop',
#     'indie poptimism',
#     'nyc pop',
#     'pop',
#     'vapor soul']},
#   {'artist': 'HAIM',
#    'id': '4Ui2kfOqGujY81UcPrb5KE',
#    'popularity': 72,
#    'genres': ['art pop',
#     'dance pop',
#     'indie pop',
#     'metropopolis',
#     'pop',
#     'pop rock',
#     'rock']},
#   {'artist': 'London Grammar',
#    'id': '3Bd1cgCjtCI32PYvDC3ynO',
#    'popularity': 72,
#    'genres': ['metropopolis', 'nottingham indie']},
#   {'artist': 'St. Lucia',
#    'id': '5WId4o5jdGVhptNU0uqKxu',
#    'popularity': 57,
#    'genres': ['alternative dance',
#     'chillwave',
#     'electropop',
#     'indie pop',
#     'indie poptimism',
#     'indietronica',
#     'metropopolis',
#     'modern alternative rock',
#     'modern rock',
#     'neo-synthpop',
#     'nyc pop',
#     'shimmer pop',
#     'vapor soul']},
#   {'artist': 'Paramore',
#    'id': '74XFHRwlV6OrjEM0A2NCMF',
#    'popularity': 80,
#    'genres': ['candy pop', 'emo', 'pixie', 'pop emo', 'pop punk']}],
#  'top_50_tracks': [{'track': 'Through the Night',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '3P3UA61WRQqwCXaoFOTENd'},
#   {'track': 'Dear Name',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '1DP0uwV6tMlCEfR61Mh7ki'},
#   {'track': 'Departures - Anata Ni Okuru Ai No Uta',
#    'artist': 'EGOIST',
#    'album': 'Extra Terrestrial Biological Entities',
#    'id': '33w7LgNJIuhs5dhSYZ0do1'},
#   {'track': 'dlwlrma',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '4NPARrLIbtMl29ZJv8ESr2'},
#   {'track': '잠 못 드는 밤 비는 내리고 [Jam Mot Deuneun Bam Bineun Naeligo] : Sleepless rainy night',
#    'artist': 'IU',
#    'album': '꽃갈피 둘 [Kkot-Galpi #2] : A flower bookmark',
#    'id': '546tamGotuR5Mhbe35ONAv'},
#   {'track': 'Me Gustas Tu',
#    'artist': 'GFRIEND',
#    'album': "GFRIEND 2nd Mini Album 'Flower Bud'",
#    'id': '6x7fux7bZEfnChKx3nhSZn'},
#   {'track': 'The Everlasting Guilty Crown',
#    'artist': 'EGOIST',
#    'album': 'Extra Terrestrial Biological Entities',
#    'id': '76jRSSkd4pLwUflgwSeuB0'},
#   {'track': 'Namae No Nai Kaibutsu',
#    'artist': 'EGOIST',
#    'album': 'Namae No Nai Kaibutsu',
#    'id': '7M2qLDA7hAwKgyrTjJfI2C'},
#   {'track': '夢灯籠',
#    'artist': 'RADWIMPS',
#    'album': '君の名は。',
#    'id': '6CsMd91gWWntqjZfXAScWe'},
#   {'track': 'Palette (Feat. G-DRAGON)',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '3y7ByLZ05tluscOTRgEJ9Y'},
#   {'track': 'Ending Scene',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '06EMBzxDm2hueehobAlMtm'},
#   {'track': 'Sparkle - movie ver.',
#    'artist': 'RADWIMPS',
#    'album': 'Your Name.',
#    'id': '3A4FRzgve9BjfKbvVXRIFO'},
#   {'track': '君の知らない物語',
#    'artist': '物語シリーズ',
#    'album': 'Utamonogatari Special Edition (Original Soundtrack)',
#    'id': '0HAi4Xk8v9JlkkxzfzPlYN'},
#   {'track': 'Some',
#    'artist': 'BOL4',
#    'album': 'Red Diary Page.1',
#    'id': '3mmLyEhphJAaW7hyEXAD8l'},
#   {'track': 'ONE-HALF',
#    'artist': 'GFRIEND',
#    'album': 'GFRIEND The 5th Mini Album <PARALLEL>',
#    'id': '5kmT53VIrf7sC2J2ja0DpA'},
#   {'track': 'Tonight',
#    'artist': '1set',
#    'album': 'Tonight',
#    'id': '5LhXvB3BI6JNdoKAxMKcfQ'},
#   {'track': 'Friday (feat.Jang Yi-jeong of HISTORY)',
#    'artist': 'IU',
#    'album': 'Modern Times ? Epilogue',
#    'id': '0GsRx0gPft6RmijIwMsKmG'},
#   {'track': 'Face Like Thunder',
#    'artist': 'The Japanese House',
#    'album': 'Swim Against the Tide',
#    'id': '3llC7WjMtxqDwaM1Gjzvrs'},
#   {'track': 'Loudspeaker',
#    'artist': 'MUNA',
#    'album': 'About U',
#    'id': '5ztCcMNmFiq5ZnID9jY9SP'},
#   {'track': 'Rough',
#    'artist': 'GFRIEND',
#    'album': 'SNOWFLAKE',
#    'id': '3CVeGXpoPKJQ9JuhPp3mpL'},
#   {'track': 'Cool Blue',
#    'artist': 'The Japanese House',
#    'album': 'Clean',
#    'id': '0Lbe98RKWwBbu1sipPSa4n'},
#   {'track': 'unlucky',
#    'artist': 'IU',
#    'album': 'Love poem',
#    'id': '1jsY6pQeNaEConZWGau1L4'},
#   {'track': 'スパークル - movie ver.',
#    'artist': 'RADWIMPS',
#    'album': '君の名は。',
#    'id': '6rOxMuxtATULp0vEaNR3RK'},
#   {'track': 'I Want To Save You',
#    'artist': 'Something Corporate',
#    'album': 'Leaving Through The Window',
#    'id': '1g5WP8pu6w2jEP0vAf5Lxk'},
#   {'track': 'Blueming',
#    'artist': 'IU',
#    'album': 'Love poem',
#    'id': '4Dr2hJ3EnVh2Aaot6fRwDO'},
#   {'track': 'lvs(var)',
#    'artist': 'Kensuke Ushio',
#    'album': 'A Shape of Light "A Silent Voice the Movie" Original Soundtrack',
#    'id': '2m6jds9zw9x5bgNXZrN4yg'},
#   {'track': '가을 아침 [Gaeul Achim] : Autumn morning',
#    'artist': 'IU',
#    'album': '꽃갈피 둘 [Kkot-Galpi #2] : A flower bookmark',
#    'id': '1MYvjx60rkxZm5oHEPKqgz'},
#   {'track': 'Time for the moon night',
#    'artist': 'GFRIEND',
#    'album': "GFRIEND The 6th Mini Album 'Time for the moon night'",
#    'id': '2jL9sjFc2LZsQBGbQnrjXR'},
#   {'track': 'Missing You / Namine (From "Kingdom Hearts II" & "Kingdom Hearts: Chain of Memories")',
#    'artist': 'daigoro789',
#    'album': 'Kingdom Hearts Piano Collections Special Edition',
#    'id': '5Cehdon3VynRhPMnAp4qmm'},
#   {'track': 'Yuri on ICE',
#    'artist': 'Taro Umebayashi',
#    'album': 'Yuri on ICE',
#    'id': '4u4t9R8Iky417ZasENaKXX'},
#   {'track': "Maybe You're the Reason",
#    'artist': 'The Japanese House',
#    'album': 'Good At Falling',
#    'id': '5Po5YmT4RhawSeqNXx5m0o'},
#   {'track': 'CHEER UP',
#    'artist': 'TWICE',
#    'album': 'PAGE TWO',
#    'id': '1D7e4LrjdB4mKaI9XYrmPY'},
#   {'track': 'LOVE WHISPER',
#    'artist': 'GFRIEND',
#    'album': 'GFRIEND The 5th Mini Album <PARALLEL>',
#    'id': '1xwnvVY9gHdo69PuGQkG1U'},
#   {'track': 'So Special',
#    'artist': 'MUNA',
#    'album': 'About U',
#    'id': '50EsWUxLBSS4nQnTuagVjF'},
#   {'track': 'Blessings (feat. Jamila Woods)',
#    'artist': 'Chance the Rapper',
#    'album': 'Coloring Book',
#    'id': '2VQc9orzwE6a5qFfy54P6e'},
#   {'track': 'Love poem',
#    'artist': 'IU',
#    'album': 'Love poem',
#    'id': '7HrE6HtYNBbGqp5GmHbFV0'},
#   {'track': '비밀의 화원 [Bimilui Hwawon] : Secret Garden',
#    'artist': 'IU',
#    'album': '꽃갈피 둘 [Kkot-Galpi #2] : A flower bookmark',
#    'id': '5F6nAnNIsRk9QbPOx9t11B'},
#   {'track': 'lit(var)',
#    'artist': 'Kensuke Ushio',
#    'album': 'A Shape of Light "A Silent Voice the Movie" Original Soundtrack',
#    'id': '6bTCdqB1PN5J93hiiZvQzW'},
#   {'track': 'I Know A Place',
#    'artist': 'MUNA',
#    'album': 'About U',
#    'id': '0bPSRn4crnh5f1JhELPlyL'},
#   {'track': 'Implicit Demand For Proof',
#    'artist': 'Twenty One Pilots',
#    'album': 'Twenty One Pilots',
#    'id': '3UaFnnUo80mv431WHEzaj9'},
#   {'track': 'Heavydirtysoul',
#    'artist': 'Twenty One Pilots',
#    'album': 'Blurryface',
#    'id': '7i9763l5SSfOnqZ35VOcfy'},
#   {'track': 'Date',
#    'artist': 'RADWIMPS',
#    'album': 'Your Name.',
#    'id': '7A7lxMWZI2Uow7WqWjWGcM'},
#   {'track': 'Popo (How deep is our love?)',
#    'artist': 'Yerin Baek',
#    'album': 'Every letter I sent you.',
#    'id': '5XAJzwa0B2Hf8Rb1q0rowN'},
#   {'track': 'Flesh without Blood',
#    'artist': 'Grimes',
#    'album': 'Art Angels',
#    'id': '4ZcGbQ5dOKX6rJk4yvza9R'},
#   {'track': 'The Taste of Ink',
#    'artist': 'The Used',
#    'album': 'The Used',
#    'id': '5jZ1Z2GFTf2gwmFc3qiUxs'},
#   {'track': 'Lullaby',
#    'artist': 'IU',
#    'album': 'Love poem',
#    'id': '7BUtoP9NXEe7MgWvIG2KGE'},
#   {'track': 'Dream lantern',
#    'artist': 'RADWIMPS',
#    'album': 'Your Name.',
#    'id': '5mEqD00bdFcsiVd0MfvEeF'},
#   {'track': 'Happy Day',
#    'artist': '1set',
#    'album': 'Sisters-in-law, Pt. 3 (Original Soundtrack)',
#    'id': '6XWJnONhIytzRvc1PXB6m7'},
#   {'track': 'Black Out',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '1sUOFqmIU38dQCA13aVKBL'},
#   {'track': 'Saw You In A Dream',
#    'artist': 'The Japanese House',
#    'album': 'Saw You In A Dream',
#    'id': '0U3u0HdRQjD8mAMYBak4Ok'}],
#  'genres': ['k-pop',
#   'j-pop',
#   'j-rock',
#   'japanese emo',
#   'visual kei',
#   'k-pop',
#   'k-pop girl group',
#   'anime',
#   'anime rock',
#   'anime score',
#   'otacore',
#   'k-pop',
#   'k-pop girl group',
#   'modern rock',
#   'pop punk',
#   'post-teen pop',
#   'art pop',
#   'electropop',
#   'indie pop',
#   'indie poptimism',
#   'indie r&b',
#   'indietronica',
#   'modern dream pop',
#   'vapor soul',
#   'japanese instrumental',
#   'otacore',
#   'scorecore',
#   'modern rock',
#   'rock',
#   'art pop',
#   'canadian electropop',
#   'chillwave',
#   'dance pop',
#   'electropop',
#   'escape room',
#   'grave wave',
#   'indie pop',
#   'indietronica',
#   'metropopolis',
#   'new rave',
#   'alternative dance',
#   'auckland indie',
#   'electropop',
#   'indie pop',
#   'indie poptimism',
#   'indie rock',
#   'indietronica',
#   'kiwi rock',
#   'metropopolis',
#   'modern rock',
#   'shimmer pop',
#   'electropop',
#   'indie pop',
#   'indie poptimism',
#   'metropopolis',
#   'neo-synthpop',
#   'shimmer pop',
#   'k-indie',
#   'k-pop',
#   'korean pop',
#   'anime rock',
#   'j-pixie',
#   'otacore',
#   'art pop',
#   'dance pop',
#   'electropop',
#   'indie electropop',
#   'indie pop',
#   'indie poptimism',
#   'la pop',
#   'metropopolis',
#   'pop',
#   'vapor soul',
#   'anti-folk',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'melancholia',
#   'omaha indie',
#   'stomp and holler',
#   'dreamo',
#   'indie rock',
#   'modern rock',
#   'alternative dance',
#   'art pop',
#   'brooklyn indie',
#   'chillwave',
#   'electropop',
#   'escape room',
#   'indie pop',
#   'metropopolis',
#   'neo-synthpop',
#   'shimmer pop',
#   'emo',
#   'pop punk',
#   'escape room',
#   'hyperpop',
#   'japanese electropop',
#   'alternative dance',
#   'canadian indie',
#   'canadian rock',
#   'dance-punk',
#   'electropop',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'metropopolis',
#   'modern rock',
#   'neo-synthpop',
#   'new rave',
#   'shimmer pop',
#   'art pop',
#   'chillwave',
#   'canadian ccm',
#   'christian alternative rock',
#   'christian music',
#   'christian punk',
#   'christian rock',
#   'emo',
#   'neo mellow',
#   'pop punk',
#   'pop rock',
#   'art pop',
#   'canadian electropop',
#   'chillwave',
#   'edmonton indie',
#   'electropop',
#   'grave wave',
#   'indietronica',
#   'metropopolis',
#   'shimmer pop',
#   'vapor soul',
#   'emo',
#   'neon pop punk',
#   'pop emo',
#   'pop punk',
#   'chicago rap',
#   'rap',
#   'post-hardcore',
#   'screamo',
#   'alternative r&b',
#   'art pop',
#   'chillwave',
#   'electropop',
#   'escape room',
#   'indie soul',
#   'metropopolis',
#   'indie rock',
#   'modern alternative rock',
#   'modern rock',
#   'rock',
#   'k-pop',
#   'korean pop',
#   'emo',
#   'neon pop punk',
#   'piano rock',
#   'pop emo',
#   'pop punk',
#   'pop rock',
#   'k-indie',
#   'k-pop',
#   'korean r&b',
#   'alternative dance',
#   'chillwave',
#   'electropop',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'metropopolis',
#   'modern rock',
#   'shimmer pop',
#   'vapor soul',
#   'anime score',
#   'eau claire indie',
#   'indie folk',
#   'melancholia',
#   'canadian indie',
#   'indie pop',
#   'indie poptimism',
#   'indie rock',
#   'lilith',
#   'metropopolis',
#   'permanent wave',
#   'pop rock',
#   'art pop',
#   'auckland indie',
#   'electropop',
#   'etherpop',
#   'indie electropop',
#   'indie pop',
#   'indie poptimism',
#   'indietronica',
#   'metropopolis',
#   'nz pop',
#   'pop',
#   'shimmer pop',
#   'tropical house',
#   'vapor soul',
#   'downtempo',
#   'dream pop',
#   'indietronica',
#   'indie pop',
#   'metropopolis',
#   'shimmer pop',
#   'stomp and holler',
#   'stomp and whittle',
#   'alternative r&b',
#   'art pop',
#   'dance pop',
#   'electropop',
#   'indie poptimism',
#   'indie r&b',
#   'pop',
#   'vapor soul',
#   'anime score',
#   'japanese soundtrack',
#   'otacore',
#   'metropopolis',
#   'modern rock',
#   'pop',
#   'pop rock',
#   'gauze pop',
#   'hopebeat',
#   'indie electropop',
#   'indie pop',
#   'indie poptimism',
#   'shimmer pop',
#   'uk pop',
#   'vapor soul',
#   'art pop',
#   'electropop',
#   'etherpop',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'alt-idol',
#   'anime',
#   'anime rock',
#   'heavy alternative',
#   'idol rock',
#   'j-idol',
#   'j-pixie',
#   'j-pop',
#   'brooklyn indie',
#   'electropop',
#   'indie electropop',
#   'indie pop',
#   'indie poptimism',
#   'nyc pop',
#   'pop',
#   'vapor soul',
#   'art pop',
#   'dance pop',
#   'indie pop',
#   'metropopolis',
#   'pop',
#   'pop rock',
#   'rock',
#   'metropopolis',
#   'nottingham indie',
#   'alternative dance',
#   'chillwave',
#   'electropop',
#   'indie pop',
#   'indie poptimism',
#   'indietronica',
#   'metropopolis',
#   'modern alternative rock',
#   'modern rock',
#   'neo-synthpop',
#   'nyc pop',
#   'shimmer pop',
#   'vapor soul',
#   'candy pop',
#   'emo',
#   'pixie',
#   'pop emo',
#   'pop punk']}

# %%
track_ids = [track['id'] for track in tracks]

#track_url = "{}/audio-features?ids=".format(SPOTIFY_API_URL)
#track_analysis_data = requests.get(track_url, headers=headers).json()

for i in track_ids:
    track_url = "{}/audio-features?ids={}".format(SPOTIFY_API_URL,i)
    track_analysis_data = requests.get(track_url, headers=headers).json()

# %%
track_url = "{}/audio-features?ids={}".format(SPOTIFY_API_URL,tracks[0]['id'])
track_analysis_data = requests.get(track_url, headers=headers).json()
track_analysis_data['audio_features']
# Out:
# [{'danceability': 0.428,
#   'energy': 0.313,
#   'key': 8,
#   'loudness': -7.327,
#   'mode': 1,
#   'speechiness': 0.0391,
#   'acousticness': 0.757,
#   'instrumentalness': 0,
#   'liveness': 0.309,
#   'valence': 0.284,
#   'tempo': 78.723,
#   'type': 'audio_features',
#   'id': '3P3UA61WRQqwCXaoFOTENd',
#   'uri': 'spotify:track:3P3UA61WRQqwCXaoFOTENd',
#   'track_href': 'https://api.spotify.com/v1/tracks/3P3UA61WRQqwCXaoFOTENd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3P3UA61WRQqwCXaoFOTENd',
#   'duration_ms': 253293,
#   'time_signature': 4}]

# %%
url = 'https://api.spotify.com/v1/me'
my_data = requests.get(url,headers = headers).json()
my_data = 'id'

# %%
user_data = requests.get(base_url,headers = headers,params=params)

artists=[]
genres=[]
popularity=[]
for i in range(limit):

    artists.append(user_data['items'][i]['name'])
    genres.append(user_data['items'][i]['genres'])
    popularity.append(user_data['items'][i]['popularity'])

# %%
print(user_data.url)

# %%
user_data['items'][0]['genres']

# %%
top50_df=pd.DataFrame({'artist':artists,
                       'genres':genres,
                       'popularity':popularity})
top50_df

# %%
#top50_df['genres'].value_counts
genres = pd.Series([x for item in top50_df.genres for x in item]).value_counts().reset_index()
genres=genres.rename(columns={'index':'genre',0:'count'})
genres.head(20)
#genre_list = genres['genre'].tolist()
#genre_list = sorted(genre_list)
#genre_list
#len(genre_list)

# %%
#use these columns for parameters for the pie chart
counts = top_genres['count']
genres = top_genres['genre']
#explode = 

#found a bunch of colors here
#https://matplotlib.org/3.1.0/gallery/color/named_colors.html
#colors = ["magenta","deepskyblue"]
#contruct plot
plt.figure(figsize = (5,5))
plt.pie(counts,labels=genres, autopct="%.1f%%", )
#plt.title("Mice Gender Distribution")
plt.axis("equal")
plt.show()

# %%
popularity_df=top50_df.sort_values('popularity',ascending=False)
popularity_df

# %%
mean_pop=popularity_df.mean()
print(popularity_df.mean())

# %%
monthly_listen=[31136355,19892244,5786789,19696892,8810802,4920540,6070574,2326642,4342067,7287210,2764446,2604646,
                4348878,4560359,2807877,1711729,2132838,2207593,1977451,1904265,999429,1423244,1654735,1925133,
               1445701,945814,1793936,1461294,1458824,820964,1734413,855722,783786,1184485,559604,928138,1055185,
               853462,1420310,1021964,436136,869287,896391,678255,307237,304716,374888,106790,337555,12476]

# %%
len(monthly_listen)

# %%
poppy=popularity_df['popularity'].tolist()

pops=[97,95,91,95,84,89,89,73,83,87,89,91,86,78,86]
listens=[60696365,55170241,41987269,48867520,21692661,21024536,21487306,7642605,1704122,24823631,
        19651875,35018530,15602696,7057663,28074532]

poppy=poppy+pops
monthly_listen=monthly_listen+listens

x_axis=poppy
y_axis=monthly_listen
len(y_axis)

# %%
#https://open.spotify.com/artist/6S2OmqARrzebs0tKUEyXyp?si=NHujpOOmS_i08KhJARSZEg

# %%
def exponential(x, a, b):
    return a*np.exp(b*x)

# %%
pars, cov = curve_fit(f=exponential, xdata=x_axis, ydata=y_axis, p0=[0, 0], bounds=(-np.inf, np.inf))

# %%
x1=np.arange(min(poppy),max(poppy)+1,1)
line_1 = pars[0]*np.exp(pars[1]*x1)

# %%
listeners=pars[0]*np.exp(pars[1]*mean_pop)
int(round(listeners,0))

# %%
plt.figure(figsize=(10,7))
plt.yticks(np.arange(0,80000000,5000000))
plt.scatter(x_axis,y_axis)
plt.ylabel('Monthly Listeners\n')
plt.xlabel('\nPopularity')
ax = plt.gca()
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

plt.plot(mean_pop,listeners,markerfacecolor='red',marker="o",markersize=10)
plt.plot(x1, line_1, linestyle='--', linewidth=1, color='black')
plt.show()

# %%
#genres['genre'] = genres['genre'].replace({'korean pop': 'k-pop',
#                                           'k-pop girl group':'k-pop',
#                                           'anime score':'anime',
#                                           'anime rock':'anime'})
top_genres=genres.iloc[:30,:]
#genres['count']

# %%
artist_list = [i for i in top50_df['artist']]

# %%
artist_list

# %%
genres = [i for i in top50_df['genres']]

# %%
genres_complete = []
for i in genres:
    for a in i:
        genres_complete.append(a)

# %%
#top tracks
user_id='me'
kind='tracks' #tracks
limit=50
token='BQA5njSRX8m-4nZmUK44XyMPOkL_uCnVKh8Zy_z6DhgY_M9-jCm7He3DrFgRivLCcbOxMug4iqTjq4wOemMkRr07qENEmFT1_nG23fH1CuX0JUwtkPqlqSGXhPPdTvMcClbCWQPyRvOFYNhIJUGolq7BVaAFmIEceiXD_FfcMpuV3hnJ38_s8VC1va4aRCrBH5ipSZtCULC8Qq4EiXa6EDmMZxcVGG1YgKsPZUQCsngAbSVPadoBahAQ_ylo4oaQ2K7PFwd0Wtp5klmW'

params={'time_range':'long_term','limit' : limit}
headers={"Accept": "application/json","Content-Type": "application/json","Authorization": 
         (f"Bearer {token}")}

#medium_term, short term

base_url=f'https://api.spotify.com/v1/{user_id}/top/{kind}?'

# %%
user_data = requests.get(base_url,headers = headers,params=params).json()

# %%
user_data

# %%
#track name
user_data['items'][0]['name']

# %%
#artist
user_data['items'][0]['album']['artists'][0]['name']

# %%
#album
user_data['items'][0]['album']['name']

# %%
#track id
user_data['items'][0]['id']

# %%
tracks = []
track_info = {}
for i in range(50):
    track_info['track'] = user_data['items'][i]['name']
    track_info['artist'] = user_data['items'][i]['album']['artists'][0]['name']
    track_info['album'] = user_data['items'][i]['album']['name']
    track_info['id'] = user_data['items'][i]['id']
    tracks.append(track_info)
    track_info = {}

# %%
tracks

# %%
import pymongo
import dns
client = pymongo.MongoClient(mongo_uri)
db = client.test

# %%
for name in client.list_database_names():  
    print(name)
# Out:
# spotify
# admin
# local

# %%
#client.spotify['user-data'].insert_one(user_data)

# %%
# for user_data in client.spotify['user-data'].find():
#     print(user_data)

# %%
client.spotify['user-data'].find()[0]['id']
# Out:
# '1275175786'

# %%
try:
    client.spotify['user-data'].replace_one(
    {"id":user_data['id']},user_data) 
except:
    client.spotify['user-data'].insert_one(user_data)

# %%
mongo_data = user_data.copy()

# %%
#mongo_data

# %%
try:
    client.spotify['user-data'].replace_one(
    {"id":mongo_data['id']},mongo_data) 
except:
    client.spotify['user-data'].insert_one(mongo_data)

# %%
client.spotify['user-data'].replace_one(
    {"id":mongo_data['id']},mongo_data)

# %%
client.spotify['user-data'].insert_one(mongo_data)

# %%
spotify_data = client.spotify['user-data'].find()

for i in range(client.spotify['user-data'].count_documents({})):
    try:
        if mongo_data['id'] == str(spotify_data[i]['id']):
            client.spotify['user-data'].replace_one(
            {"id":mongo_data['id']},mongo_data)
            break
        else:
            client.spotify['user-data'].insert_one(mongo_data)
            break
    except:
        pass

# %%
#mongo_data

# %%
spotify_data[0]['id']
# Out:
# '1275175786'

# %%
mongo_data = {'id' : '1275175786', 'test' : 'True', 'zz' : 5245}

# %%
for i in range(client.spotify['user-data'].count_documents({})):
    print(type(spotify_data[i]['id']))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
type(mongo_data['id'])
# Out:
# str

# %%
str(spotify_data[i]['id'])
# Out:
# '1275175786'

# %%
client.spotify['user-data'].replace_one(
            {"id":mongo_data['id']},mongo_data, upsert = True)

# %%
track_ids = [track['id'] for track in mongo_data['top_50_tracks']]

# %%
track_ids
# Out:
# ['3P3UA61WRQqwCXaoFOTENd',
#  '1DP0uwV6tMlCEfR61Mh7ki',
#  '33w7LgNJIuhs5dhSYZ0do1',
#  '4NPARrLIbtMl29ZJv8ESr2',
#  '546tamGotuR5Mhbe35ONAv',
#  '6x7fux7bZEfnChKx3nhSZn',
#  '76jRSSkd4pLwUflgwSeuB0',
#  '7M2qLDA7hAwKgyrTjJfI2C',
#  '6CsMd91gWWntqjZfXAScWe',
#  '3y7ByLZ05tluscOTRgEJ9Y',
#  '06EMBzxDm2hueehobAlMtm',
#  '3A4FRzgve9BjfKbvVXRIFO',
#  '0HAi4Xk8v9JlkkxzfzPlYN',
#  '3mmLyEhphJAaW7hyEXAD8l',
#  '5kmT53VIrf7sC2J2ja0DpA',
#  '5LhXvB3BI6JNdoKAxMKcfQ',
#  '0GsRx0gPft6RmijIwMsKmG',
#  '3llC7WjMtxqDwaM1Gjzvrs',
#  '5ztCcMNmFiq5ZnID9jY9SP',
#  '3CVeGXpoPKJQ9JuhPp3mpL',
#  '0Lbe98RKWwBbu1sipPSa4n',
#  '1jsY6pQeNaEConZWGau1L4',
#  '6rOxMuxtATULp0vEaNR3RK',
#  '1g5WP8pu6w2jEP0vAf5Lxk',
#  '4Dr2hJ3EnVh2Aaot6fRwDO',
#  '2m6jds9zw9x5bgNXZrN4yg',
#  '1MYvjx60rkxZm5oHEPKqgz',
#  '2jL9sjFc2LZsQBGbQnrjXR',
#  '5Cehdon3VynRhPMnAp4qmm',
#  '4u4t9R8Iky417ZasENaKXX',
#  '5Po5YmT4RhawSeqNXx5m0o',
#  '1D7e4LrjdB4mKaI9XYrmPY',
#  '1xwnvVY9gHdo69PuGQkG1U',
#  '50EsWUxLBSS4nQnTuagVjF',
#  '2VQc9orzwE6a5qFfy54P6e',
#  '7HrE6HtYNBbGqp5GmHbFV0',
#  '5F6nAnNIsRk9QbPOx9t11B',
#  '6bTCdqB1PN5J93hiiZvQzW',
#  '0bPSRn4crnh5f1JhELPlyL',
#  '3UaFnnUo80mv431WHEzaj9',
#  '7i9763l5SSfOnqZ35VOcfy',
#  '7A7lxMWZI2Uow7WqWjWGcM',
#  '5XAJzwa0B2Hf8Rb1q0rowN',
#  '4ZcGbQ5dOKX6rJk4yvza9R',
#  '5jZ1Z2GFTf2gwmFc3qiUxs',
#  '7BUtoP9NXEe7MgWvIG2KGE',
#  '5mEqD00bdFcsiVd0MfvEeF',
#  '6XWJnONhIytzRvc1PXB6m7',
#  '1sUOFqmIU38dQCA13aVKBL',
#  '0U3u0HdRQjD8mAMYBak4Ok']
