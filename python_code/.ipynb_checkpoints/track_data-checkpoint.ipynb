# %%
#modules
import pymongo
import dns
import matplotlib.pyplot as plt
import pandas as pd
import requests
import numpy as np
from datetime import date
from config import mongo_uri
import pprint
import json

# %%
#connect to mongo db
client = pymongo.MongoClient(mongo_uri)

# %%
#looking at all the names for users in the database
for i in client.spotify['user-data'].find():
     print(i['name'])
# Out:
# Hunter Havins
# Henry Byoun
# Avery Davis Lamb
# Mitch Klee
# Jonathan
# Daniel Suh
# Derrik
# Maanasa Neralla
# Anish Patel
# shazib.iqbal
# Asher Waqar
# Madison Monteiro
# Blair Moore
# Shivani Ghadia
# Pooja Krishnaswamy
# Ben Pollock
# Brendan Legas
# conorg3462
# Kalashi De Silva
# Rohan
# saiahj97

# %% [markdown]
# ### Averages

# %%
all_users = client.spotify['user-data'].find()
db_len = int(client.spotify['user-data'].count_documents({}))

unique_genres_all = []
for i in range(db_len):
    unique_genres_all.append(len(np.unique(all_users[i]['genres'])))

average_genres = int(round(np.mean(unique_genres_all)))

# %%
pop =[]
for i in range(db_len):
    try:
        pop.append(all_users[i]['average_artist_popularity'])
    except:
        pass

all_avg = int(round(np.mean(pop)))


all_artists = []
artist_counts = []
for i in range(db_len):
    for k in range(len(all_users[i]['top_50_artists'])):
        all_artists.append(all_users[i]['top_50_artists'][k]['artist'])

b = Counter(all_artists)
#print(b.most_common(10))
most_common = []
most_common_value = []
for i in range(10):
    most_common.append(b.most_common(10)[i][0])
    most_common_value.append(b.most_common(10)[i][1])

# %%
all_user_stats = {}
all_user_stats['average_unique_genres'] = average_genres

# %%
all_user_stats['average_alluser_artist_popularity'] = all_avg
all_user_stats['most_common_artists'] = most_common
all_user_stats['most_common_artists_counts'] = most_common_value

# %%
all_user_stats
# Out:
# {'average_unique_genres': 80,
#  'average_alluser_artist_popularity': 73,
#  'most_common_artists': ['Kanye West',
#   'Drake',
#   'Kendrick Lamar',
#   'The Weeknd',
#   'Travis Scott',
#   'J. Cole',
#   'Post Malone',
#   'Khalid',
#   'Migos',
#   'Future'],
#  'most_common_artists_counts': [17, 15, 12, 11, 11, 10, 10, 9, 9, 9]}

# %%
with open('../data/all_user_stats.json', 'w') as json_file:
    json.dump(user_stats, json_file)

# %%
user_stats['average_unique_genres'] = average_genres

# %%
user_stats['average_alluser_artist_popularity'] = all_avg
        user_stats['most_common_artists'] = most_common
        user_stats['most_common_artists_counts'] = most_common_value

# %%
mygenres = client.spotify['user-data'].find({'name':'Henry Byoun'})[0]['genres']

# %%
unique_genres = len(np.unique(mygenres))
unique_genres
# Out:
# 94

# %%
all_users = client.spotify['user-data'].find()
db_len = int(client.spotify['user-data'].count_documents({}))

# %%
unique_genres_all = []
for i in range(db_len):
    unique_genres_all.append(len(np.unique(all_users[i]['genres'])))

# %%
average_genres = int(round(np.mean(unique_genres_all)))
average_genres
# Out:
# 81

# %%
avg_pop = client.spotify['user-data'].find({'name':'Henry Byoun'})[0]['average_artist_popularity']
avg_pop
# Out:
# 65

# %%
all_users = client.spotify['user-data'].find({})
pop =[]
for i in range(db_len):
    try:
        pop.append(all_users[i]['average_artist_popularity'])
    except:
        pass
  
all_avg = int(round(np.mean(pop)))

# %%
all_avg
# Out:
# 65

# %%
all_artists = []
artist_counts = []
for i in range(db_len):
    for k in range(len(all_users[i]['top_50_artists'])):
        all_artists.append(all_users[i]['top_50_artists'][k]['artist'])

# %%
from collections import Counter

b = Counter(all_artists)
#print(b.most_common(10))
most_common = []
most_common_value = []
for i in range(10):
    most_common.append(b.most_common(10)[i][0])
    most_common_value.append(b.most_common(10)[i][1])

# %%
most_common
# Out:
# ['Kanye West',
#  'Drake',
#  'Kendrick Lamar',
#  'The Weeknd',
#  'Travis Scott',
#  'J. Cole',
#  'Post Malone',
#  'Khalid',
#  'Migos',
#  'Future']

# %%
most_common_value
# Out:
# [17, 15, 12, 11, 11, 10, 10, 9, 9, 9]

# %%
user_stats = {}
user_stats['user_unique_genres'] = unique_genres
user_stats['average_unique_genres'] = average_genres
user_stats['average_user_artist_popularity'] = avg_pop
user_stats['average_alluser_artist_popularity'] = all_avg
user_stats['most_common_artists'] = most_common
user_stats['most_common_artists_counts'] = most_common_value

# %%
user_stats
# Out:
# {'user_unique_genres': 94,
#  'average_unique_genres': 81,
#  'average_user_artist_popularity': 65,
#  'average_alluser_artist_popularity': 65,
#  'most_common_artists': ['Kanye West',
#   'Drake',
#   'Kendrick Lamar',
#   'The Weeknd',
#   'Travis Scott',
#   'J. Cole',
#   'Post Malone',
#   'Khalid',
#   'Migos',
#   'Future'],
#  'most_common_artists_counts': [17, 15, 12, 11, 11, 10, 10, 9, 9, 9]}

# %% [markdown]
# ## Following script just takes the track data from a single user. Here we will be using my (Henry's) data. First we can query a user by their name and then extract the audio analysis data from their top 50 tracks.

# %%
#use the parameter inside find() to query a specific document in the collection
#here I am querying Henry's data by declaring {'name' : 'Henry'}

henry_top_tracks = client.spotify['user-data'].find({'name':'Henry Byoun'})[0]['top_50_artists']
#henry_top_tracks[0]['audio_features'][0]
#frend = client.spotify['user-data'].find({'name':'Madison Monteiro'})[0]['top_50_artists']

# for i in henry_top_tracks:
#     print(i['artist'])

# %%
# for i in frend:
#     print(i['artist'])

# %%
name = []
artist = []
album = []
track_id = []
danceability = []
energy = []
key = []
loudness = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []
duration_ms = []


for i in range(len(henry_top_tracks)):
    name.append(henry_top_tracks[i]['track'])
    artist.append(henry_top_tracks[i]['artist'])
    album.append(henry_top_tracks[i]['album'])
    track_id.append(henry_top_tracks[i]['id'])
    danceability.append(henry_top_tracks[i]['audio_features'][0]['danceability'])
    energy.append(henry_top_tracks[i]['audio_features'][0]['energy'])
    key.append(henry_top_tracks[i]['audio_features'][0]['key'])
    loudness.append(henry_top_tracks[i]['audio_features'][0]['loudness'])   
    speechiness.append(henry_top_tracks[i]['audio_features'][0]['speechiness'])  
    acousticness.append(henry_top_tracks[i]['audio_features'][0]['acousticness']) 
    instrumentalness.append(henry_top_tracks[i]['audio_features'][0]['instrumentalness']) 
    liveness.append(henry_top_tracks[i]['audio_features'][0]['liveness']) 
    valence.append(henry_top_tracks[i]['audio_features'][0]['valence'])  
    tempo.append(henry_top_tracks[i]['audio_features'][0]['tempo'])  
    duration_ms.append(henry_top_tracks[i]['audio_features'][0]['duration_ms'])

# %%
henry_tracks = pd.DataFrame({'name':name,
                       'artist':artist,
                       'album': album,
                       'track_id': track_id,
                       'danceability':danceability,
                       'energy':energy,
                       'key':key,
                       'loudness':loudness,
                       'speechiness':speechiness,
                       'acousticness': acousticness,
                       'instrumentalness': instrumentalness,
                       'liveness':liveness,
                       'valence':valence,
                       'tempo':tempo,
                       'duration_ms':duration_ms
                       })

# %%
henry_tracks.head()

# %%
henry_tracks.to_csv('../data/henrys_track_data.csv', index = False)

# %% [markdown]
# ## Similar script below but now we will query all of the tracks from all users

# %%
all_top_tracks = client.spotify['user-data'].find()
db_len = int(client.spotify['user-data'].count_documents({}))

# %%
name = []
artist = []
album = []
track_id = []
danceability = []
energy = []
key = []
loudness = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []
duration_ms = []


top_tracks = []
for k in range(db_len):
    top_tracks.append(all_top_tracks[k]['top_50_tracks'])
    
for ii in range(len(top_tracks)):   
    for i in range(len(top_tracks[ii])):
        name.append(top_tracks[ii][i]['track'])
        artist.append(top_tracks[ii][i]['artist'])
        album.append(top_tracks[ii][i]['album'])
        track_id.append(top_tracks[ii][i]['id'])
        danceability.append(top_tracks[ii][i]['audio_features'][0]['danceability'])
        energy.append(top_tracks[ii][i]['audio_features'][0]['energy'])
        key.append(top_tracks[ii][i]['audio_features'][0]['key'])
        loudness.append(top_tracks[ii][i]['audio_features'][0]['loudness'])   
        speechiness.append(top_tracks[ii][i]['audio_features'][0]['speechiness'])  
        acousticness.append(top_tracks[ii][i]['audio_features'][0]['acousticness']) 
        instrumentalness.append(top_tracks[ii][i]['audio_features'][0]['instrumentalness']) 
        liveness.append(top_tracks[ii][i]['audio_features'][0]['liveness']) 
        valence.append(top_tracks[ii][i]['audio_features'][0]['valence'])  
        tempo.append(top_tracks[ii][i]['audio_features'][0]['tempo'])  
        duration_ms.append(top_tracks[ii][i]['audio_features'][0]['duration_ms'])

# %%
print(len(name))
print(len(artist))
print(len(album))
print(len(track_id))
print(len(danceability))
print(len(energy))
print(len(key))
print(len(loudness))
print(len(speechiness))
print(len(acousticness))
print(len(instrumentalness))
print(len(liveness))
print(len(valence))
print(len(tempo))
print(len(duration_ms))

# %%
all_user_tracks = pd.DataFrame({'name':name,
                       'artist':artist,
                       'album': album,
                       'track_id': track_id,
                       'danceability':danceability,
                       'energy':energy,
                       'key':key,
                       'loudness':loudness,
                       'speechiness':speechiness,
                       'acousticness': acousticness,
                       'instrumentalness': instrumentalness,
                       'liveness':liveness,
                       'valence':valence,
                       'tempo':tempo,
                       'duration_ms':duration_ms
                       })

# %%
all_user_tracks.to_csv('../data/all_user_track_data.csv', index = False)

# %%
all_user_tracks.head()

# %% [markdown]
# # Writing JSON file based on my data

# %%
henrys_data = client.spotify['user-data'].find({'name':'Henry Byoun'})[0]
#henrys_data

# %%
#remove the mongo_db index, not jsonable data
henrys_data.pop('_id', None)
# Out:
# ObjectId('5f83b79d84cc2e1c63f65f9e')

# %%
with open('../data/henry_data.json', 'w') as json_file:
    json.dump(henrys_data, json_file)

# %%
henrys_data
# Out:
# {'date_updated': '10/19/2020',
#  'name': 'Henry Byoun',
#  'id': '1275175786',
#  'user_image_url': 'https://scontent-ort2-2.xx.fbcdn.net/v/t1.0-1/s320x320/116431759_10224385201443935_222815006266796964_o.jpg?_nc_cat=111&_nc_sid=0c64ff&_nc_ohc=mQwvydKd6ooAX_pQLLX&_nc_ht=scontent-ort2-2.xx&tp=7&oh=913d0d5a39e053f10b2042626a49f2ac&oe=5FB329FB',
#  'top_50_artists': [{'artist': 'IU',
#    'id': '3HqSLMAZ3g3d5poNaI7GOU',
#    'image': 'https://i.scdn.co/image/51ccdd82404ba316a096b3b97f88286aacb42c5d',
#    'popularity': 77,
#    'genres': ['k-pop']},
#   {'artist': 'RADWIMPS',
#    'id': '1EowJ1WwkMzkCkRomFhui7',
#    'image': 'https://i.scdn.co/image/dcce11b6c3797bba9852892dda99b85cf4c58861',
#    'popularity': 75,
#    'genres': ['j-pop', 'j-rock', 'japanese emo', 'visual kei']},
#   {'artist': 'TWICE',
#    'id': '7n2Ycct7Beij7Dj7meI4X0',
#    'image': 'https://i.scdn.co/image/2329c39c9c2fe817cdaa89dfca2ce857793cb0a0',
#    'popularity': 82,
#    'genres': ['k-pop', 'k-pop girl group']},
#   {'artist': 'EGOIST',
#    'id': '0k7JZhYS35IewiKNHW7KMj',
#    'image': 'https://i.scdn.co/image/b2adbd8f6c5e72bfece4d02957a08cec20e53831',
#    'popularity': 58,
#    'genres': ['anime', 'anime rock', 'anime score', 'otacore']},
#   {'artist': 'GFRIEND',
#    'id': '0qlWcS66ohOIi0M8JZwPft',
#    'image': 'https://i.scdn.co/image/8ee83a75b24e0942b9b3da221d59266bc554486c',
#    'popularity': 67,
#    'genres': ['k-pop', 'k-pop girl group']},
#   {'artist': 'All Time Low',
#    'id': '46gyXjRIvN1NL1eCB8GBxo',
#    'image': 'https://i.scdn.co/image/12ca3775837790e8c7da4a7d5cd34f9381cd39c1',
#    'popularity': 75,
#    'genres': ['modern rock', 'pop punk']},
#   {'artist': 'The Japanese House',
#    'id': '3IunaFjvNKj98JW89JYv9u',
#    'image': 'https://i.scdn.co/image/848b92c2487efb37ba4c75bc25a242c7b2785440',
#    'popularity': 67,
#    'genres': ['art pop',
#     'electropop',
#     'indie pop',
#     'indie poptimism',
#     'indietronica',
#     'modern dream pop',
#     'vapor soul']},
#   {'artist': 'daigoro789',
#    'id': '6dOnTTVTbQlFWF6yfD4Vw5',
#    'image': 'https://i.scdn.co/image/ab67616d0000b2738e15e42231dfc19703c321eb',
#    'popularity': 62,
#    'genres': ['japanese instrumental', 'otacore', 'scorecore']},
#   {'artist': 'Twenty One Pilots',
#    'id': '3YQKmKGau1PzlVlkL1iodx',
#    'image': 'https://i.scdn.co/image/19e8f3bc875b7a4b9cf0041a5ee696c4be5478aa',
#    'popularity': 86,
#    'genres': ['modern rock', 'rock']},
#   {'artist': 'Grimes',
#    'id': '053q0ukIDRgzwTr4vNSwab',
#    'image': 'https://i.scdn.co/image/40023d857fb2f0735ffd743b28cf4f6ea2b627f1',
#    'popularity': 73,
#    'genres': ['art pop',
#     'canadian electropop',
#     'chillwave',
#     'dance pop',
#     'electropop',
#     'escape room',
#     'grave wave',
#     'indie pop',
#     'indietronica',
#     'metropopolis']},
#   {'artist': 'The Naked And Famous',
#    'id': '0oeUpvxWsC8bWS6SnpU8b9',
#    'image': 'https://i.scdn.co/image/d7ccf7c470088d7b47b2f33e6ffbf4ff469fddbd',
#    'popularity': 63,
#    'genres': ['alternative dance',
#     'auckland indie',
#     'electropop',
#     'indie pop',
#     'indie poptimism',
#     'indie rock',
#     'indietronica',
#     'kiwi rock',
#     'metropopolis',
#     'modern rock',
#     'shimmer pop']},
#   {'artist': 'CHVRCHES',
#    'id': '3CjlHNtplJyTf9npxaPl5w',
#    'image': 'https://i.scdn.co/image/e6c530da12f920f3b8d2d57be7782f9d49af16c3',
#    'popularity': 72,
#    'genres': ['electropop',
#     'indie pop',
#     'indie poptimism',
#     'metropopolis',
#     'neo-synthpop',
#     'shimmer pop']},
#   {'artist': 'Yerin Baek',
#    'id': '6dhfy4ByARPJdPtMyrUYJK',
#    'image': 'https://i.scdn.co/image/9a9e9301d3492dc86cb7bc8c021cd1d97cc5e214',
#    'popularity': 63,
#    'genres': ['k-indie', 'k-pop', 'korean pop']},
#   {'artist': 'LiSA',
#    'id': '0blbVefuxOGltDBa00dspv',
#    'image': 'https://i.scdn.co/image/cff0577c3fffc72fa6add5ed0c2b48fb547654e0',
#    'popularity': 75,
#    'genres': ['anime rock', 'j-pixie', 'otacore']},
#   {'artist': 'MUNA',
#    'id': '6xdRb2GypJ7DqnWAI2mHGn',
#    'image': 'https://i.scdn.co/image/dd5fd579ed05981c6228104e83c8f5b1f584c8b1',
#    'popularity': 62,
#    'genres': ['art pop',
#     'dance pop',
#     'electropop',
#     'indie electropop',
#     'indie pop',
#     'indie poptimism',
#     'la pop',
#     'metropopolis',
#     'pop',
#     'vapor soul']},
#   {'artist': 'Bright Eyes',
#    'id': '5o206eFLx38glA2bb4zqIU',
#    'image': 'https://i.scdn.co/image/8b097679f496de83d93c2560062fa8f7a3d9af09',
#    'popularity': 65,
#    'genres': ['anti-folk',
#     'indie folk',
#     'indie pop',
#     'indie rock',
#     'melancholia',
#     'omaha indie',
#     'stomp and holler']},
#   {'artist': 'Manchester Orchestra',
#    'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#    'image': 'https://i.scdn.co/image/a231fe0b0bbd00d25f33bb7dd065644ea8b3d2fe',
#    'popularity': 62,
#    'genres': ['dreamo', 'indie rock', 'modern rock']},
#   {'artist': 'Chairlift',
#    'id': '7hAolICGSgXJuM6DUpK5rp',
#    'image': 'https://i.scdn.co/image/103c030de25759eb1a4c7d092d4c57b119141a58',
#    'popularity': 49,
#    'genres': ['alternative dance',
#     'art pop',
#     'brooklyn indie',
#     'chillwave',
#     'electropop',
#     'escape room',
#     'indie pop',
#     'metropopolis',
#     'neo-synthpop',
#     'shimmer pop']},
#   {'artist': 'Taking Back Sunday',
#    'id': '24XtlMhEMNdi822vi0MhY1',
#    'image': 'https://i.scdn.co/image/563bb4b3776fbbea7c05575b1fe33d4c0db255de',
#    'popularity': 65,
#    'genres': ['emo', 'pop punk']},
#   {'artist': 'Kero Kero Bonito',
#    'id': '6OqhFYFJDnBBHas02HopPT',
#    'image': 'https://i.scdn.co/image/102231ea5a5d013c778c73bbf84d0ce5b6b0d973',
#    'popularity': 63,
#    'genres': ['escape room', 'hyperpop', 'japanese electropop']},
#   {'artist': 'Metric',
#    'id': '1rCIEwPp5OnXW0ornlSsRl',
#    'image': 'https://i.scdn.co/image/e59862715ef4e242a8d835b8d41a7fe60249e151',
#    'popularity': 63,
#    'genres': ['alternative dance',
#     'canadian indie',
#     'canadian rock',
#     'dance-punk',
#     'electropop',
#     'indie pop',
#     'indie rock',
#     'indietronica',
#     'metropopolis',
#     'modern rock',
#     'neo-synthpop',
#     'new rave',
#     'shimmer pop']},
#   {'artist': 'Mr Twin Sister',
#    'id': '5ltJZgIW3OkY5WvuzX5MYz',
#    'image': 'https://i.scdn.co/image/4d747c9bb1d4a8b8aab106ba522f892f1f2d994c',
#    'popularity': 50,
#    'genres': ['art pop', 'chillwave']},
#   {'artist': 'Relient K',
#    'id': '3nJWBJvK7uGvfp4iZh9CkN',
#    'image': 'https://i.scdn.co/image/15ae3465f22a282d3d7cd40f45e768437c0d2c74',
#    'popularity': 61,
#    'genres': ['canadian ccm',
#     'christian alternative rock',
#     'christian music',
#     'christian punk',
#     'christian rock',
#     'indiecoustica',
#     'neo mellow',
#     'pop punk',
#     'pop rock']},
#   {'artist': 'Purity Ring',
#    'id': '1TtJ8j22Roc24e2Jx3OcU4',
#    'image': 'https://i.scdn.co/image/184e0129877999ec5541c123117cffeca5e9efaf',
#    'popularity': 61,
#    'genres': ['art pop',
#     'canadian electropop',
#     'chillwave',
#     'edmonton indie',
#     'electropop',
#     'grave wave',
#     'indietronica',
#     'metropopolis',
#     'shimmer pop',
#     'vapor soul']},
#   {'artist': 'Mayday Parade',
#    'id': '3WfJ1OtrWI7RViX9DMyEGy',
#    'image': 'https://i.scdn.co/image/300891e76b60cf1702687bcc337fea9bf95b327d',
#    'popularity': 68,
#    'genres': ['emo', 'neon pop punk', 'pop emo', 'pop punk']},
#   {'artist': 'Kanye West',
#    'id': '5K4W6rqBFWDnAN6FQUkS6x',
#    'image': 'https://i.scdn.co/image/bd1c6fdf3705cf9b7d0c8ac8e7bbed98e31a1559',
#    'popularity': 92,
#    'genres': ['chicago rap', 'hip hop', 'rap']},
#   {'artist': 'The Used',
#    'id': '55VydwMyCuGcavwPuhutPL',
#    'image': 'https://i.scdn.co/image/0f476171f283207656e95e1005cea7040be475d7',
#    'popularity': 69,
#    'genres': ['post-hardcore', 'screamo']},
#   {'artist': 'Blood Orange',
#    'id': '6LEeAFiJF8OuPx747e1wxR',
#    'image': 'https://i.scdn.co/image/b28cc2c93be5abb0765e30df21dd2c44446292bb',
#    'popularity': 68,
#    'genres': ['alternative r&b',
#     'art pop',
#     'chillwave',
#     'electropop',
#     'escape room',
#     'indie soul',
#     'metropopolis']},
#   {'artist': 'Wolf Alice',
#    'id': '3btzEQD6sugImIHPMRgkwV',
#    'image': 'https://i.scdn.co/image/af531125938c7d8cd4625e19e6d73c6bef4b4810',
#    'popularity': 60,
#    'genres': ['indie rock', 'modern alternative rock', 'modern rock', 'rock']},
#   {'artist': 'BOL4',
#    'id': '4k5fFEYgkWYrYvtOK3zVBl',
#    'image': 'https://i.scdn.co/image/167e4a3dc83e53dd7493b8d1b95a6aff9c5d1d50',
#    'popularity': 69,
#    'genres': ['k-pop', 'korean pop']},
#   {'artist': 'Something Corporate',
#    'id': '71h7GTahhKcSkQ1ayhTvOD',
#    'image': 'https://i.scdn.co/image/5fe4b58edb8b1b9c876bf547e6322170a48f6362',
#    'popularity': 50,
#    'genres': ['emo',
#     'neon pop punk',
#     'piano rock',
#     'pop emo',
#     'pop punk',
#     'pop rock']},
#   {'artist': 'SURAN',
#    'id': '1mORehSVEd7lcaT2d7Sl2K',
#    'image': 'https://i.scdn.co/image/a4f03c94c556336da4745dbe7fb293dd29da6704',
#    'popularity': 61,
#    'genres': ['k-indie', 'k-pop', 'korean r&b']},
#   {'artist': 'Phantogram',
#    'id': '1l9d7B8W0IHy3LqWsxP2SH',
#    'image': 'https://i.scdn.co/image/6a21c2a74396a24e8d5d7f1d78d3126c0b5216ee',
#    'popularity': 63,
#    'genres': ['alternative dance',
#     'chillwave',
#     'electropop',
#     'indie pop',
#     'indie rock',
#     'indietronica',
#     'metropopolis',
#     'modern rock',
#     'shimmer pop',
#     'vapor soul']},
#   {'artist': '藤澤慶昌',
#    'id': '1sNFJ2IaKm03L1qQs2wZw6',
#    'image': 'https://i.scdn.co/image/ab67616d0000b273b4e7138a43e6c7a4023d835a',
#    'popularity': 37,
#    'genres': ['anime score']},
#   {'artist': 'Bon Iver',
#    'id': '4LEiUm1SRbFMgfqnQTwUbQ',
#    'image': 'https://i.scdn.co/image/d5ea2b221938b03e2096ef2c2caf2a0558014c1e',
#    'popularity': 81,
#    'genres': ['eau claire indie', 'indie folk', 'melancholia']},
#   {'artist': 'Tegan and Sara',
#    'id': '5e1BZulIiYWPRm8yogwUYH',
#    'image': 'https://i.scdn.co/image/b76fc13dceaf22570fbb20ef01d82da142d356a7',
#    'popularity': 63,
#    'genres': ['canadian indie',
#     'indie pop',
#     'indie poptimism',
#     'indie rock',
#     'lilith',
#     'metropopolis',
#     'permanent wave',
#     'pop rock']},
#   {'artist': 'Broods',
#    'id': '5r5Va4lVQ1zjEfbJSrmCsS',
#    'image': 'https://i.scdn.co/image/8da05eabfc44a308fb5c6b19d9411d52771fafcf',
#    'popularity': 63,
#    'genres': ['art pop',
#     'auckland indie',
#     'electropop',
#     'etherpop',
#     'indie electropop',
#     'indie pop',
#     'indie poptimism',
#     'indietronica',
#     'metropopolis',
#     'nz pop',
#     'pop',
#     'shimmer pop',
#     'tropical house',
#     'vapor soul']},
#   {'artist': 'The xx',
#    'id': '3iOvXCl6edW5Um0fXEBRXy',
#    'image': 'https://i.scdn.co/image/922163afa546eca372c27be4513a481de06e9481',
#    'popularity': 72,
#    'genres': ['downtempo', 'dream pop', 'indietronica']},
#   {'artist': 'Kishi Bashi',
#    'id': '3LVPGE5jPPwtbGslx07YR0',
#    'image': 'https://i.scdn.co/image/4dbf2f3c378f9ec16e41b418193c736cd7363178',
#    'popularity': 55,
#    'genres': ['indie pop',
#     'metropopolis',
#     'shimmer pop',
#     'stomp and holler',
#     'stomp and whittle']},
#   {'artist': 'BANKS',
#    'id': '2xe8IXgCTpwHE3eA9hTs4n',
#    'image': 'https://i.scdn.co/image/18b753a034aae665dfd164c8ee8e8e81ba5f5e47',
#    'popularity': 67,
#    'genres': ['alternative r&b',
#     'art pop',
#     'dance pop',
#     'electropop',
#     'indie poptimism',
#     'pop',
#     'vapor soul']},
#   {'artist': 'Kensuke Ushio',
#    'id': '4L0gz16xuM1as1OgYzh1SR',
#    'image': 'https://i.scdn.co/image/3d7d99b9f3b21c73136d472b47725f20cc6410e8',
#    'popularity': 61,
#    'genres': ['anime score', 'japanese soundtrack', 'otacore']},
#   {'artist': 'Bastille',
#    'id': '7EQ0qTo7fWT7DPxmxtSYEc',
#    'image': 'https://i.scdn.co/image/979eca18c0cb1796426d101ce0e14939c95a6be3',
#    'popularity': 81,
#    'genres': ['metropopolis', 'modern rock', 'pop', 'pop rock']},
#   {'artist': 'Fickle Friends',
#    'id': '1nhSLEYdoBHG6cJ8NDwoF1',
#    'image': 'https://i.scdn.co/image/34685ed0975a9c81881a9db03cd69471bfa290a5',
#    'popularity': 51,
#    'genres': ['gauze pop',
#     'hopebeat',
#     'indie pop',
#     'indie poptimism',
#     'shimmer pop',
#     'uk pop',
#     'vapor soul']},
#   {'artist': 'Sylvan Esso',
#    'id': '39vA9YljbnOApXKniLWBZv',
#    'image': 'https://i.scdn.co/image/a9488380277cdce61ed6f625e70278c8cff8e4ce',
#    'popularity': 69,
#    'genres': ['art pop',
#     'electropop',
#     'etherpop',
#     'indie folk',
#     'indie pop',
#     'indie rock']},
#   {'artist': 'SILENT SIREN',
#    'id': '11FVEsg4m3QWzNfaK7vykQ',
#    'image': 'https://i.scdn.co/image/8bbf704eacef2a0935b600c92b6f667db4d9cc99',
#    'popularity': 50,
#    'genres': ['alt-idol',
#     'anime',
#     'anime rock',
#     'heavy alternative',
#     'idol rock',
#     'j-idol',
#     'j-pixie',
#     'j-pop']},
#   {'artist': 'Wet',
#    'id': '2i9uaNzfUtuApAjEf1omV8',
#    'image': 'https://i.scdn.co/image/e7b21a6394695ceea40a22f6d98f71fd50cb9762',
#    'popularity': 60,
#    'genres': ['brooklyn indie',
#     'electropop',
#     'indie electropop',
#     'indie pop',
#     'indie poptimism',
#     'nyc pop',
#     'pop',
#     'vapor soul']},
#   {'artist': 'HAIM',
#    'id': '4Ui2kfOqGujY81UcPrb5KE',
#    'image': 'https://i.scdn.co/image/89f4d643a8eae22f667288c4510bc43bb3c5cb1e',
#    'popularity': 72,
#    'genres': ['art pop',
#     'dance pop',
#     'indie pop',
#     'metropopolis',
#     'pop',
#     'pop rock',
#     'rock']},
#   {'artist': 'London Grammar',
#    'id': '3Bd1cgCjtCI32PYvDC3ynO',
#    'image': 'https://i.scdn.co/image/e3918969a81d252c5691f2b9339bd46e82bdd4da',
#    'popularity': 72,
#    'genres': ['metropopolis', 'nottingham indie']},
#   {'artist': 'Barrie',
#    'id': '1pHO6SCEw9tuRx0IVMFL0g',
#    'image': 'https://i.scdn.co/image/a4c5129260bc78102596a9a06fb2d553e187da05',
#    'popularity': 50,
#    'genres': ['brooklyn indie', 'indie rock', 'vapor soul']},
#   {'artist': 'St. Lucia',
#    'id': '5WId4o5jdGVhptNU0uqKxu',
#    'image': 'https://i.scdn.co/image/3e6aa92ab34ac29f575a51cd0af2deeed7969435',
#    'popularity': 57,
#    'genres': ['alternative dance',
#     'chillwave',
#     'electropop',
#     'indie pop',
#     'indie poptimism',
#     'indietronica',
#     'metropopolis',
#     'modern alternative rock',
#     'modern rock',
#     'neo-synthpop',
#     'nyc pop',
#     'shimmer pop',
#     'vapor soul']}],
#  'top_50_tracks': [{'track': 'Through the Night',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '3P3UA61WRQqwCXaoFOTENd',
#    'track_url': 'https://open.spotify.com/embed/track/3P3UA61WRQqwCXaoFOTENd',
#    'audio_features': [{'danceability': 0.428,
#      'energy': 0.313,
#      'key': 8,
#      'loudness': -7.327,
#      'mode': 1,
#      'speechiness': 0.0391,
#      'acousticness': 0.757,
#      'instrumentalness': 0,
#      'liveness': 0.309,
#      'valence': 0.284,
#      'tempo': 78.723,
#      'type': 'audio_features',
#      'id': '3P3UA61WRQqwCXaoFOTENd',
#      'uri': 'spotify:track:3P3UA61WRQqwCXaoFOTENd',
#      'track_href': 'https://api.spotify.com/v1/tracks/3P3UA61WRQqwCXaoFOTENd',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3P3UA61WRQqwCXaoFOTENd',
#      'duration_ms': 253293,
#      'time_signature': 4}]},
#   {'track': 'Dear Name',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '1DP0uwV6tMlCEfR61Mh7ki',
#    'track_url': 'https://open.spotify.com/embed/track/1DP0uwV6tMlCEfR61Mh7ki',
#    'audio_features': [{'danceability': 0.312,
#      'energy': 0.589,
#      'key': 2,
#      'loudness': -5.071,
#      'mode': 1,
#      'speechiness': 0.0334,
#      'acousticness': 0.459,
#      'instrumentalness': 0,
#      'liveness': 0.106,
#      'valence': 0.237,
#      'tempo': 133.854,
#      'type': 'audio_features',
#      'id': '1DP0uwV6tMlCEfR61Mh7ki',
#      'uri': 'spotify:track:1DP0uwV6tMlCEfR61Mh7ki',
#      'track_href': 'https://api.spotify.com/v1/tracks/1DP0uwV6tMlCEfR61Mh7ki',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DP0uwV6tMlCEfR61Mh7ki',
#      'duration_ms': 289580,
#      'time_signature': 3}]},
#   {'track': 'Departures - Anata Ni Okuru Ai No Uta',
#    'artist': 'EGOIST',
#    'album': 'Extra Terrestrial Biological Entities',
#    'id': '33w7LgNJIuhs5dhSYZ0do1',
#    'track_url': 'https://open.spotify.com/embed/track/33w7LgNJIuhs5dhSYZ0do1',
#    'audio_features': [{'danceability': 0.473,
#      'energy': 0.431,
#      'key': 2,
#      'loudness': -8.172,
#      'mode': 1,
#      'speechiness': 0.0305,
#      'acousticness': 0.493,
#      'instrumentalness': 0,
#      'liveness': 0.0752,
#      'valence': 0.283,
#      'tempo': 143.862,
#      'type': 'audio_features',
#      'id': '33w7LgNJIuhs5dhSYZ0do1',
#      'uri': 'spotify:track:33w7LgNJIuhs5dhSYZ0do1',
#      'track_href': 'https://api.spotify.com/v1/tracks/33w7LgNJIuhs5dhSYZ0do1',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33w7LgNJIuhs5dhSYZ0do1',
#      'duration_ms': 255013,
#      'time_signature': 4}]},
#   {'track': 'dlwlrma',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '4NPARrLIbtMl29ZJv8ESr2',
#    'track_url': 'https://open.spotify.com/embed/track/4NPARrLIbtMl29ZJv8ESr2',
#    'audio_features': [{'danceability': 0.738,
#      'energy': 0.641,
#      'key': 4,
#      'loudness': -3.44,
#      'mode': 1,
#      'speechiness': 0.0475,
#      'acousticness': 0.315,
#      'instrumentalness': 0,
#      'liveness': 0.114,
#      'valence': 0.631,
#      'tempo': 119.867,
#      'type': 'audio_features',
#      'id': '4NPARrLIbtMl29ZJv8ESr2',
#      'uri': 'spotify:track:4NPARrLIbtMl29ZJv8ESr2',
#      'track_href': 'https://api.spotify.com/v1/tracks/4NPARrLIbtMl29ZJv8ESr2',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NPARrLIbtMl29ZJv8ESr2',
#      'duration_ms': 176099,
#      'time_signature': 4}]},
#   {'track': '잠 못 드는 밤 비는 내리고 [Jam Mot Deuneun Bam Bineun Naeligo] : Sleepless rainy night',
#    'artist': 'IU',
#    'album': '꽃갈피 둘 [Kkot-Galpi #2] : A flower bookmark',
#    'id': '546tamGotuR5Mhbe35ONAv',
#    'track_url': 'https://open.spotify.com/embed/track/546tamGotuR5Mhbe35ONAv',
#    'audio_features': [{'danceability': 0.761,
#      'energy': 0.456,
#      'key': 10,
#      'loudness': -7.817,
#      'mode': 1,
#      'speechiness': 0.0461,
#      'acousticness': 0.727,
#      'instrumentalness': 0.000103,
#      'liveness': 0.143,
#      'valence': 0.46,
#      'tempo': 91.028,
#      'type': 'audio_features',
#      'id': '546tamGotuR5Mhbe35ONAv',
#      'uri': 'spotify:track:546tamGotuR5Mhbe35ONAv',
#      'track_href': 'https://api.spotify.com/v1/tracks/546tamGotuR5Mhbe35ONAv',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/546tamGotuR5Mhbe35ONAv',
#      'duration_ms': 266517,
#      'time_signature': 4}]},
#   {'track': 'Me Gustas Tu',
#    'artist': 'GFRIEND',
#    'album': "GFRIEND 2nd Mini Album 'Flower Bud'",
#    'id': '6x7fux7bZEfnChKx3nhSZn',
#    'track_url': 'https://open.spotify.com/embed/track/6x7fux7bZEfnChKx3nhSZn',
#    'audio_features': [{'danceability': 0.646,
#      'energy': 0.923,
#      'key': 8,
#      'loudness': -1.309,
#      'mode': 1,
#      'speechiness': 0.0613,
#      'acousticness': 0.166,
#      'instrumentalness': 0,
#      'liveness': 0.0507,
#      'valence': 0.703,
#      'tempo': 106.086,
#      'type': 'audio_features',
#      'id': '6x7fux7bZEfnChKx3nhSZn',
#      'uri': 'spotify:track:6x7fux7bZEfnChKx3nhSZn',
#      'track_href': 'https://api.spotify.com/v1/tracks/6x7fux7bZEfnChKx3nhSZn',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6x7fux7bZEfnChKx3nhSZn',
#      'duration_ms': 220745,
#      'time_signature': 4}]},
#   {'track': 'The Everlasting Guilty Crown',
#    'artist': 'EGOIST',
#    'album': 'Extra Terrestrial Biological Entities',
#    'id': '76jRSSkd4pLwUflgwSeuB0',
#    'track_url': 'https://open.spotify.com/embed/track/76jRSSkd4pLwUflgwSeuB0',
#    'audio_features': [{'danceability': 0.35,
#      'energy': 0.935,
#      'key': 1,
#      'loudness': -4.368,
#      'mode': 0,
#      'speechiness': 0.0907,
#      'acousticness': 0.00731,
#      'instrumentalness': 1.79e-05,
#      'liveness': 0.339,
#      'valence': 0.333,
#      'tempo': 171.993,
#      'type': 'audio_features',
#      'id': '76jRSSkd4pLwUflgwSeuB0',
#      'uri': 'spotify:track:76jRSSkd4pLwUflgwSeuB0',
#      'track_href': 'https://api.spotify.com/v1/tracks/76jRSSkd4pLwUflgwSeuB0',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/76jRSSkd4pLwUflgwSeuB0',
#      'duration_ms': 325320,
#      'time_signature': 4}]},
#   {'track': '名前のない怪物',
#    'artist': 'EGOIST',
#    'album': 'Namae No Nai Kaibutsu',
#    'id': '7M2qLDA7hAwKgyrTjJfI2C',
#    'track_url': 'https://open.spotify.com/embed/track/7M2qLDA7hAwKgyrTjJfI2C',
#    'audio_features': [{'danceability': 0.338,
#      'energy': 0.896,
#      'key': 10,
#      'loudness': -5.984,
#      'mode': 1,
#      'speechiness': 0.171,
#      'acousticness': 0.000236,
#      'instrumentalness': 0.000705,
#      'liveness': 0.311,
#      'valence': 0.237,
#      'tempo': 179.832,
#      'type': 'audio_features',
#      'id': '7M2qLDA7hAwKgyrTjJfI2C',
#      'uri': 'spotify:track:7M2qLDA7hAwKgyrTjJfI2C',
#      'track_href': 'https://api.spotify.com/v1/tracks/7M2qLDA7hAwKgyrTjJfI2C',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7M2qLDA7hAwKgyrTjJfI2C',
#      'duration_ms': 317267,
#      'time_signature': 4}]},
#   {'track': '夢灯籠',
#    'artist': 'RADWIMPS',
#    'album': '君の名は。',
#    'id': '6CsMd91gWWntqjZfXAScWe',
#    'track_url': 'https://open.spotify.com/embed/track/6CsMd91gWWntqjZfXAScWe',
#    'audio_features': [{'danceability': 0.213,
#      'energy': 0.864,
#      'key': 8,
#      'loudness': -5.71,
#      'mode': 1,
#      'speechiness': 0.401,
#      'acousticness': 0.0301,
#      'instrumentalness': 9.68e-05,
#      'liveness': 0.0465,
#      'valence': 0.13,
#      'tempo': 177.921,
#      'type': 'audio_features',
#      'id': '6CsMd91gWWntqjZfXAScWe',
#      'uri': 'spotify:track:6CsMd91gWWntqjZfXAScWe',
#      'track_href': 'https://api.spotify.com/v1/tracks/6CsMd91gWWntqjZfXAScWe',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6CsMd91gWWntqjZfXAScWe',
#      'duration_ms': 129187,
#      'time_signature': 3}]},
#   {'track': 'Palette (Feat. G-DRAGON)',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '3y7ByLZ05tluscOTRgEJ9Y',
#    'track_url': 'https://open.spotify.com/embed/track/3y7ByLZ05tluscOTRgEJ9Y',
#    'audio_features': [{'danceability': 0.804,
#      'energy': 0.68,
#      'key': 0,
#      'loudness': -3.81,
#      'mode': 1,
#      'speechiness': 0.2,
#      'acousticness': 0.458,
#      'instrumentalness': 0,
#      'liveness': 0.102,
#      'valence': 0.62,
#      'tempo': 102.013,
#      'type': 'audio_features',
#      'id': '3y7ByLZ05tluscOTRgEJ9Y',
#      'uri': 'spotify:track:3y7ByLZ05tluscOTRgEJ9Y',
#      'track_href': 'https://api.spotify.com/v1/tracks/3y7ByLZ05tluscOTRgEJ9Y',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3y7ByLZ05tluscOTRgEJ9Y',
#      'duration_ms': 217413,
#      'time_signature': 4}]},
#   {'track': 'Ending Scene',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '06EMBzxDm2hueehobAlMtm',
#    'track_url': 'https://open.spotify.com/embed/track/06EMBzxDm2hueehobAlMtm',
#    'audio_features': [{'danceability': 0.388,
#      'energy': 0.323,
#      'key': 5,
#      'loudness': -7.158,
#      'mode': 1,
#      'speechiness': 0.0348,
#      'acousticness': 0.851,
#      'instrumentalness': 2.03e-06,
#      'liveness': 0.143,
#      'valence': 0.232,
#      'tempo': 118.885,
#      'type': 'audio_features',
#      'id': '06EMBzxDm2hueehobAlMtm',
#      'uri': 'spotify:track:06EMBzxDm2hueehobAlMtm',
#      'track_href': 'https://api.spotify.com/v1/tracks/06EMBzxDm2hueehobAlMtm',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/06EMBzxDm2hueehobAlMtm',
#      'duration_ms': 249242,
#      'time_signature': 4}]},
#   {'track': 'Sparkle - movie ver.',
#    'artist': 'RADWIMPS',
#    'album': 'Your Name.',
#    'id': '3A4FRzgve9BjfKbvVXRIFO',
#    'track_url': 'https://open.spotify.com/embed/track/3A4FRzgve9BjfKbvVXRIFO',
#    'audio_features': [{'danceability': 0.372,
#      'energy': 0.426,
#      'key': 11,
#      'loudness': -8.421,
#      'mode': 1,
#      'speechiness': 0.0339,
#      'acousticness': 0.687,
#      'instrumentalness': 0.00784,
#      'liveness': 0.109,
#      'valence': 0.287,
#      'tempo': 123.993,
#      'type': 'audio_features',
#      'id': '3A4FRzgve9BjfKbvVXRIFO',
#      'uri': 'spotify:track:3A4FRzgve9BjfKbvVXRIFO',
#      'track_href': 'https://api.spotify.com/v1/tracks/3A4FRzgve9BjfKbvVXRIFO',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3A4FRzgve9BjfKbvVXRIFO',
#      'duration_ms': 537653,
#      'time_signature': 4}]},
#   {'track': '君の知らない物語',
#    'artist': '物語シリーズ',
#    'album': 'Utamonogatari Special Edition (Original Soundtrack)',
#    'id': '0HAi4Xk8v9JlkkxzfzPlYN',
#    'track_url': 'https://open.spotify.com/embed/track/0HAi4Xk8v9JlkkxzfzPlYN',
#    'audio_features': [{'danceability': 0.422,
#      'energy': 0.914,
#      'key': 9,
#      'loudness': -2.828,
#      'mode': 1,
#      'speechiness': 0.046,
#      'acousticness': 0.00963,
#      'instrumentalness': 0,
#      'liveness': 0.0744,
#      'valence': 0.529,
#      'tempo': 164.876,
#      'type': 'audio_features',
#      'id': '0HAi4Xk8v9JlkkxzfzPlYN',
#      'uri': 'spotify:track:0HAi4Xk8v9JlkkxzfzPlYN',
#      'track_href': 'https://api.spotify.com/v1/tracks/0HAi4Xk8v9JlkkxzfzPlYN',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0HAi4Xk8v9JlkkxzfzPlYN',
#      'duration_ms': 344053,
#      'time_signature': 4}]},
#   {'track': 'Some',
#    'artist': 'BOL4',
#    'album': 'Red Diary Page.1',
#    'id': '3mmLyEhphJAaW7hyEXAD8l',
#    'track_url': 'https://open.spotify.com/embed/track/3mmLyEhphJAaW7hyEXAD8l',
#    'audio_features': [{'danceability': 0.659,
#      'energy': 0.799,
#      'key': 1,
#      'loudness': -2.849,
#      'mode': 0,
#      'speechiness': 0.0629,
#      'acousticness': 0.417,
#      'instrumentalness': 0,
#      'liveness': 0.0562,
#      'valence': 0.782,
#      'tempo': 103.99,
#      'type': 'audio_features',
#      'id': '3mmLyEhphJAaW7hyEXAD8l',
#      'uri': 'spotify:track:3mmLyEhphJAaW7hyEXAD8l',
#      'track_href': 'https://api.spotify.com/v1/tracks/3mmLyEhphJAaW7hyEXAD8l',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3mmLyEhphJAaW7hyEXAD8l',
#      'duration_ms': 181373,
#      'time_signature': 4}]},
#   {'track': 'ONE-HALF',
#    'artist': 'GFRIEND',
#    'album': 'GFRIEND The 5th Mini Album <PARALLEL>',
#    'id': '5kmT53VIrf7sC2J2ja0DpA',
#    'track_url': 'https://open.spotify.com/embed/track/5kmT53VIrf7sC2J2ja0DpA',
#    'audio_features': [{'danceability': 0.684,
#      'energy': 0.898,
#      'key': 6,
#      'loudness': -1.242,
#      'mode': 0,
#      'speechiness': 0.0402,
#      'acousticness': 0.208,
#      'instrumentalness': 0,
#      'liveness': 0.0403,
#      'valence': 0.487,
#      'tempo': 122.973,
#      'type': 'audio_features',
#      'id': '5kmT53VIrf7sC2J2ja0DpA',
#      'uri': 'spotify:track:5kmT53VIrf7sC2J2ja0DpA',
#      'track_href': 'https://api.spotify.com/v1/tracks/5kmT53VIrf7sC2J2ja0DpA',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5kmT53VIrf7sC2J2ja0DpA',
#      'duration_ms': 214058,
#      'time_signature': 4}]},
#   {'track': 'Tonight',
#    'artist': '1set',
#    'album': 'Tonight',
#    'id': '5LhXvB3BI6JNdoKAxMKcfQ',
#    'track_url': 'https://open.spotify.com/embed/track/5LhXvB3BI6JNdoKAxMKcfQ',
#    'audio_features': [{'danceability': 0.697,
#      'energy': 0.567,
#      'key': 4,
#      'loudness': -4.657,
#      'mode': 0,
#      'speechiness': 0.0403,
#      'acousticness': 0.737,
#      'instrumentalness': 0,
#      'liveness': 0.118,
#      'valence': 0.485,
#      'tempo': 94.984,
#      'type': 'audio_features',
#      'id': '5LhXvB3BI6JNdoKAxMKcfQ',
#      'uri': 'spotify:track:5LhXvB3BI6JNdoKAxMKcfQ',
#      'track_href': 'https://api.spotify.com/v1/tracks/5LhXvB3BI6JNdoKAxMKcfQ',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5LhXvB3BI6JNdoKAxMKcfQ',
#      'duration_ms': 226359,
#      'time_signature': 4}]},
#   {'track': 'Friday (feat.Jang Yi-jeong of HISTORY)',
#    'artist': 'IU',
#    'album': 'Modern Times ? Epilogue',
#    'id': '0GsRx0gPft6RmijIwMsKmG',
#    'track_url': 'https://open.spotify.com/embed/track/0GsRx0gPft6RmijIwMsKmG',
#    'audio_features': [{'danceability': 0.693,
#      'energy': 0.529,
#      'key': 9,
#      'loudness': -4.819,
#      'mode': 1,
#      'speechiness': 0.0539,
#      'acousticness': 0.56,
#      'instrumentalness': 0,
#      'liveness': 0.111,
#      'valence': 0.555,
#      'tempo': 80.026,
#      'type': 'audio_features',
#      'id': '0GsRx0gPft6RmijIwMsKmG',
#      'uri': 'spotify:track:0GsRx0gPft6RmijIwMsKmG',
#      'track_href': 'https://api.spotify.com/v1/tracks/0GsRx0gPft6RmijIwMsKmG',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0GsRx0gPft6RmijIwMsKmG',
#      'duration_ms': 217156,
#      'time_signature': 4}]},
#   {'track': 'Face Like Thunder',
#    'artist': 'The Japanese House',
#    'album': 'Swim Against the Tide',
#    'id': '3llC7WjMtxqDwaM1Gjzvrs',
#    'track_url': 'https://open.spotify.com/embed/track/3llC7WjMtxqDwaM1Gjzvrs',
#    'audio_features': [{'danceability': 0.636,
#      'energy': 0.742,
#      'key': 0,
#      'loudness': -6.751,
#      'mode': 1,
#      'speechiness': 0.039,
#      'acousticness': 0.233,
#      'instrumentalness': 3.87e-05,
#      'liveness': 0.185,
#      'valence': 0.285,
#      'tempo': 119.951,
#      'type': 'audio_features',
#      'id': '3llC7WjMtxqDwaM1Gjzvrs',
#      'uri': 'spotify:track:3llC7WjMtxqDwaM1Gjzvrs',
#      'track_href': 'https://api.spotify.com/v1/tracks/3llC7WjMtxqDwaM1Gjzvrs',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3llC7WjMtxqDwaM1Gjzvrs',
#      'duration_ms': 237427,
#      'time_signature': 4}]},
#   {'track': 'Loudspeaker',
#    'artist': 'MUNA',
#    'album': 'About U',
#    'id': '5ztCcMNmFiq5ZnID9jY9SP',
#    'track_url': 'https://open.spotify.com/embed/track/5ztCcMNmFiq5ZnID9jY9SP',
#    'audio_features': [{'danceability': 0.678,
#      'energy': 0.871,
#      'key': 9,
#      'loudness': -4.319,
#      'mode': 1,
#      'speechiness': 0.0569,
#      'acousticness': 0.489,
#      'instrumentalness': 2.04e-06,
#      'liveness': 0.189,
#      'valence': 0.679,
#      'tempo': 119.019,
#      'type': 'audio_features',
#      'id': '5ztCcMNmFiq5ZnID9jY9SP',
#      'uri': 'spotify:track:5ztCcMNmFiq5ZnID9jY9SP',
#      'track_href': 'https://api.spotify.com/v1/tracks/5ztCcMNmFiq5ZnID9jY9SP',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ztCcMNmFiq5ZnID9jY9SP',
#      'duration_ms': 210053,
#      'time_signature': 4}]},
#   {'track': 'Rough',
#    'artist': 'GFRIEND',
#    'album': 'SNOWFLAKE',
#    'id': '3CVeGXpoPKJQ9JuhPp3mpL',
#    'track_url': 'https://open.spotify.com/embed/track/3CVeGXpoPKJQ9JuhPp3mpL',
#    'audio_features': [{'danceability': 0.613,
#      'energy': 0.912,
#      'key': 8,
#      'loudness': -2.464,
#      'mode': 1,
#      'speechiness': 0.0366,
#      'acousticness': 0.152,
#      'instrumentalness': 0,
#      'liveness': 0.111,
#      'valence': 0.734,
#      'tempo': 112.005,
#      'type': 'audio_features',
#      'id': '3CVeGXpoPKJQ9JuhPp3mpL',
#      'uri': 'spotify:track:3CVeGXpoPKJQ9JuhPp3mpL',
#      'track_href': 'https://api.spotify.com/v1/tracks/3CVeGXpoPKJQ9JuhPp3mpL',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3CVeGXpoPKJQ9JuhPp3mpL',
#      'duration_ms': 209105,
#      'time_signature': 4}]},
#   {'track': 'Cool Blue',
#    'artist': 'The Japanese House',
#    'album': 'Clean',
#    'id': '0Lbe98RKWwBbu1sipPSa4n',
#    'track_url': 'https://open.spotify.com/embed/track/0Lbe98RKWwBbu1sipPSa4n',
#    'audio_features': [{'danceability': 0.607,
#      'energy': 0.566,
#      'key': 0,
#      'loudness': -10.37,
#      'mode': 1,
#      'speechiness': 0.0482,
#      'acousticness': 0.895,
#      'instrumentalness': 0.083,
#      'liveness': 0.139,
#      'valence': 0.607,
#      'tempo': 180.048,
#      'type': 'audio_features',
#      'id': '0Lbe98RKWwBbu1sipPSa4n',
#      'uri': 'spotify:track:0Lbe98RKWwBbu1sipPSa4n',
#      'track_href': 'https://api.spotify.com/v1/tracks/0Lbe98RKWwBbu1sipPSa4n',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Lbe98RKWwBbu1sipPSa4n',
#      'duration_ms': 231333,
#      'time_signature': 3}]},
#   {'track': 'unlucky',
#    'artist': 'IU',
#    'album': 'Love poem',
#    'id': '1jsY6pQeNaEConZWGau1L4',
#    'track_url': 'https://open.spotify.com/embed/track/1jsY6pQeNaEConZWGau1L4',
#    'audio_features': [{'danceability': 0.528,
#      'energy': 0.482,
#      'key': 10,
#      'loudness': -3.689,
#      'mode': 1,
#      'speechiness': 0.0444,
#      'acousticness': 0.836,
#      'instrumentalness': 0,
#      'liveness': 0.136,
#      'valence': 0.505,
#      'tempo': 169.907,
#      'type': 'audio_features',
#      'id': '1jsY6pQeNaEConZWGau1L4',
#      'uri': 'spotify:track:1jsY6pQeNaEConZWGau1L4',
#      'track_href': 'https://api.spotify.com/v1/tracks/1jsY6pQeNaEConZWGau1L4',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1jsY6pQeNaEConZWGau1L4',
#      'duration_ms': 231133,
#      'time_signature': 4}]},
#   {'track': 'スパークル - movie ver.',
#    'artist': 'RADWIMPS',
#    'album': '君の名は。',
#    'id': '6rOxMuxtATULp0vEaNR3RK',
#    'track_url': 'https://open.spotify.com/embed/track/6rOxMuxtATULp0vEaNR3RK',
#    'audio_features': [{'danceability': 0.374,
#      'energy': 0.432,
#      'key': 11,
#      'loudness': -8.395,
#      'mode': 1,
#      'speechiness': 0.0334,
#      'acousticness': 0.691,
#      'instrumentalness': 0.00649,
#      'liveness': 0.109,
#      'valence': 0.295,
#      'tempo': 124.012,
#      'type': 'audio_features',
#      'id': '6rOxMuxtATULp0vEaNR3RK',
#      'uri': 'spotify:track:6rOxMuxtATULp0vEaNR3RK',
#      'track_href': 'https://api.spotify.com/v1/tracks/6rOxMuxtATULp0vEaNR3RK',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6rOxMuxtATULp0vEaNR3RK',
#      'duration_ms': 534120,
#      'time_signature': 4}]},
#   {'track': 'I Want To Save You',
#    'artist': 'Something Corporate',
#    'album': 'Leaving Through The Window',
#    'id': '1g5WP8pu6w2jEP0vAf5Lxk',
#    'track_url': 'https://open.spotify.com/embed/track/1g5WP8pu6w2jEP0vAf5Lxk',
#    'audio_features': [{'danceability': 0.451,
#      'energy': 0.863,
#      'key': 3,
#      'loudness': -5.917,
#      'mode': 1,
#      'speechiness': 0.0361,
#      'acousticness': 0.00107,
#      'instrumentalness': 0.000157,
#      'liveness': 0.123,
#      'valence': 0.344,
#      'tempo': 148.074,
#      'type': 'audio_features',
#      'id': '1g5WP8pu6w2jEP0vAf5Lxk',
#      'uri': 'spotify:track:1g5WP8pu6w2jEP0vAf5Lxk',
#      'track_href': 'https://api.spotify.com/v1/tracks/1g5WP8pu6w2jEP0vAf5Lxk',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1g5WP8pu6w2jEP0vAf5Lxk',
#      'duration_ms': 262267,
#      'time_signature': 4}]},
#   {'track': 'Blueming',
#    'artist': 'IU',
#    'album': 'Love poem',
#    'id': '4Dr2hJ3EnVh2Aaot6fRwDO',
#    'track_url': 'https://open.spotify.com/embed/track/4Dr2hJ3EnVh2Aaot6fRwDO',
#    'audio_features': [{'danceability': 0.819,
#      'energy': 0.674,
#      'key': 0,
#      'loudness': -3.145,
#      'mode': 1,
#      'speechiness': 0.0587,
#      'acousticness': 0.0849,
#      'instrumentalness': 0,
#      'liveness': 0.0667,
#      'valence': 0.682,
#      'tempo': 106.032,
#      'type': 'audio_features',
#      'id': '4Dr2hJ3EnVh2Aaot6fRwDO',
#      'uri': 'spotify:track:4Dr2hJ3EnVh2Aaot6fRwDO',
#      'track_href': 'https://api.spotify.com/v1/tracks/4Dr2hJ3EnVh2Aaot6fRwDO',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Dr2hJ3EnVh2Aaot6fRwDO',
#      'duration_ms': 217053,
#      'time_signature': 4}]},
#   {'track': 'lvs(var)',
#    'artist': 'Kensuke Ushio',
#    'album': 'A Shape of Light "A Silent Voice the Movie" Original Soundtrack',
#    'id': '2m6jds9zw9x5bgNXZrN4yg',
#    'track_url': 'https://open.spotify.com/embed/track/2m6jds9zw9x5bgNXZrN4yg',
#    'audio_features': [{'danceability': 0.592,
#      'energy': 0.173,
#      'key': 7,
#      'loudness': -20.698,
#      'mode': 1,
#      'speechiness': 0.0373,
#      'acousticness': 0.941,
#      'instrumentalness': 0.972,
#      'liveness': 0.0947,
#      'valence': 0.433,
#      'tempo': 69.999,
#      'type': 'audio_features',
#      'id': '2m6jds9zw9x5bgNXZrN4yg',
#      'uri': 'spotify:track:2m6jds9zw9x5bgNXZrN4yg',
#      'track_href': 'https://api.spotify.com/v1/tracks/2m6jds9zw9x5bgNXZrN4yg',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2m6jds9zw9x5bgNXZrN4yg',
#      'duration_ms': 85520,
#      'time_signature': 4}]},
#   {'track': '가을 아침 [Gaeul Achim] : Autumn morning',
#    'artist': 'IU',
#    'album': '꽃갈피 둘 [Kkot-Galpi #2] : A flower bookmark',
#    'id': '1MYvjx60rkxZm5oHEPKqgz',
#    'track_url': 'https://open.spotify.com/embed/track/1MYvjx60rkxZm5oHEPKqgz',
#    'audio_features': [{'danceability': 0.571,
#      'energy': 0.316,
#      'key': 9,
#      'loudness': -7.22,
#      'mode': 1,
#      'speechiness': 0.142,
#      'acousticness': 0.785,
#      'instrumentalness': 0,
#      'liveness': 0.376,
#      'valence': 0.547,
#      'tempo': 170.901,
#      'type': 'audio_features',
#      'id': '1MYvjx60rkxZm5oHEPKqgz',
#      'uri': 'spotify:track:1MYvjx60rkxZm5oHEPKqgz',
#      'track_href': 'https://api.spotify.com/v1/tracks/1MYvjx60rkxZm5oHEPKqgz',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1MYvjx60rkxZm5oHEPKqgz',
#      'duration_ms': 218885,
#      'time_signature': 4}]},
#   {'track': 'Time for the moon night',
#    'artist': 'GFRIEND',
#    'album': "GFRIEND The 6th Mini Album 'Time for the moon night'",
#    'id': '2jL9sjFc2LZsQBGbQnrjXR',
#    'track_url': 'https://open.spotify.com/embed/track/2jL9sjFc2LZsQBGbQnrjXR',
#    'audio_features': [{'danceability': 0.455,
#      'energy': 0.827,
#      'key': 6,
#      'loudness': -1.201,
#      'mode': 1,
#      'speechiness': 0.0573,
#      'acousticness': 0.325,
#      'instrumentalness': 0,
#      'liveness': 0.0473,
#      'valence': 0.681,
#      'tempo': 169.929,
#      'type': 'audio_features',
#      'id': '2jL9sjFc2LZsQBGbQnrjXR',
#      'uri': 'spotify:track:2jL9sjFc2LZsQBGbQnrjXR',
#      'track_href': 'https://api.spotify.com/v1/tracks/2jL9sjFc2LZsQBGbQnrjXR',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2jL9sjFc2LZsQBGbQnrjXR',
#      'duration_ms': 226699,
#      'time_signature': 4}]},
#   {'track': 'Missing You / Namine (From "Kingdom Hearts II" & "Kingdom Hearts: Chain of Memories")',
#    'artist': 'daigoro789',
#    'album': 'Kingdom Hearts Piano Collections Special Edition',
#    'id': '5Cehdon3VynRhPMnAp4qmm',
#    'track_url': 'https://open.spotify.com/embed/track/5Cehdon3VynRhPMnAp4qmm',
#    'audio_features': [{'danceability': 0.506,
#      'energy': 0.0357,
#      'key': 5,
#      'loudness': -26.807,
#      'mode': 1,
#      'speechiness': 0.0633,
#      'acousticness': 0.984,
#      'instrumentalness': 0.884,
#      'liveness': 0.13,
#      'valence': 0.073,
#      'tempo': 125.719,
#      'type': 'audio_features',
#      'id': '5Cehdon3VynRhPMnAp4qmm',
#      'uri': 'spotify:track:5Cehdon3VynRhPMnAp4qmm',
#      'track_href': 'https://api.spotify.com/v1/tracks/5Cehdon3VynRhPMnAp4qmm',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Cehdon3VynRhPMnAp4qmm',
#      'duration_ms': 298347,
#      'time_signature': 3}]},
#   {'track': 'Yuri on ICE',
#    'artist': 'Taro Umebayashi',
#    'album': 'Yuri on ICE',
#    'id': '4u4t9R8Iky417ZasENaKXX',
#    'track_url': 'https://open.spotify.com/embed/track/4u4t9R8Iky417ZasENaKXX',
#    'audio_features': [{'danceability': 0.176,
#      'energy': 0.514,
#      'key': 8,
#      'loudness': -12.05,
#      'mode': 1,
#      'speechiness': 0.0308,
#      'acousticness': 0.816,
#      'instrumentalness': 0.637,
#      'liveness': 0.117,
#      'valence': 0.154,
#      'tempo': 80.018,
#      'type': 'audio_features',
#      'id': '4u4t9R8Iky417ZasENaKXX',
#      'uri': 'spotify:track:4u4t9R8Iky417ZasENaKXX',
#      'track_href': 'https://api.spotify.com/v1/tracks/4u4t9R8Iky417ZasENaKXX',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4u4t9R8Iky417ZasENaKXX',
#      'duration_ms': 220999,
#      'time_signature': 4}]},
#   {'track': "Maybe You're the Reason",
#    'artist': 'The Japanese House',
#    'album': 'Good At Falling',
#    'id': '5Po5YmT4RhawSeqNXx5m0o',
#    'track_url': 'https://open.spotify.com/embed/track/5Po5YmT4RhawSeqNXx5m0o',
#    'audio_features': [{'danceability': 0.621,
#      'energy': 0.762,
#      'key': 5,
#      'loudness': -6.376,
#      'mode': 1,
#      'speechiness': 0.0328,
#      'acousticness': 0.106,
#      'instrumentalness': 2.71e-06,
#      'liveness': 0.302,
#      'valence': 0.395,
#      'tempo': 95.014,
#      'type': 'audio_features',
#      'id': '5Po5YmT4RhawSeqNXx5m0o',
#      'uri': 'spotify:track:5Po5YmT4RhawSeqNXx5m0o',
#      'track_href': 'https://api.spotify.com/v1/tracks/5Po5YmT4RhawSeqNXx5m0o',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Po5YmT4RhawSeqNXx5m0o',
#      'duration_ms': 218936,
#      'time_signature': 4}]},
#   {'track': 'CHEER UP',
#    'artist': 'TWICE',
#    'album': 'PAGE TWO',
#    'id': '1D7e4LrjdB4mKaI9XYrmPY',
#    'track_url': 'https://open.spotify.com/embed/track/1D7e4LrjdB4mKaI9XYrmPY',
#    'audio_features': [{'danceability': 0.548,
#      'energy': 0.885,
#      'key': 6,
#      'loudness': -1.48,
#      'mode': 1,
#      'speechiness': 0.125,
#      'acousticness': 0.139,
#      'instrumentalness': 0,
#      'liveness': 0.0716,
#      'valence': 0.509,
#      'tempo': 172.946,
#      'type': 'audio_features',
#      'id': '1D7e4LrjdB4mKaI9XYrmPY',
#      'uri': 'spotify:track:1D7e4LrjdB4mKaI9XYrmPY',
#      'track_href': 'https://api.spotify.com/v1/tracks/1D7e4LrjdB4mKaI9XYrmPY',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1D7e4LrjdB4mKaI9XYrmPY',
#      'duration_ms': 208862,
#      'time_signature': 4}]},
#   {'track': 'LOVE WHISPER',
#    'artist': 'GFRIEND',
#    'album': 'GFRIEND The 5th Mini Album <PARALLEL>',
#    'id': '1xwnvVY9gHdo69PuGQkG1U',
#    'track_url': 'https://open.spotify.com/embed/track/1xwnvVY9gHdo69PuGQkG1U',
#    'audio_features': [{'danceability': 0.711,
#      'energy': 0.928,
#      'key': 8,
#      'loudness': -1.666,
#      'mode': 0,
#      'speechiness': 0.0484,
#      'acousticness': 0.126,
#      'instrumentalness': 0,
#      'liveness': 0.335,
#      'valence': 0.577,
#      'tempo': 114.012,
#      'type': 'audio_features',
#      'id': '1xwnvVY9gHdo69PuGQkG1U',
#      'uri': 'spotify:track:1xwnvVY9gHdo69PuGQkG1U',
#      'track_href': 'https://api.spotify.com/v1/tracks/1xwnvVY9gHdo69PuGQkG1U',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1xwnvVY9gHdo69PuGQkG1U',
#      'duration_ms': 211972,
#      'time_signature': 4}]},
#   {'track': 'So Special',
#    'artist': 'MUNA',
#    'album': 'About U',
#    'id': '50EsWUxLBSS4nQnTuagVjF',
#    'track_url': 'https://open.spotify.com/embed/track/50EsWUxLBSS4nQnTuagVjF',
#    'audio_features': [{'danceability': 0.558,
#      'energy': 0.77,
#      'key': 2,
#      'loudness': -5.107,
#      'mode': 1,
#      'speechiness': 0.0407,
#      'acousticness': 0.0889,
#      'instrumentalness': 3.22e-06,
#      'liveness': 0.29,
#      'valence': 0.545,
#      'tempo': 90.943,
#      'type': 'audio_features',
#      'id': '50EsWUxLBSS4nQnTuagVjF',
#      'uri': 'spotify:track:50EsWUxLBSS4nQnTuagVjF',
#      'track_href': 'https://api.spotify.com/v1/tracks/50EsWUxLBSS4nQnTuagVjF',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50EsWUxLBSS4nQnTuagVjF',
#      'duration_ms': 237013,
#      'time_signature': 4}]},
#   {'track': 'Blessings (feat. Jamila Woods)',
#    'artist': 'Chance the Rapper',
#    'album': 'Coloring Book',
#    'id': '2VQc9orzwE6a5qFfy54P6e',
#    'track_url': 'https://open.spotify.com/embed/track/2VQc9orzwE6a5qFfy54P6e',
#    'audio_features': [{'danceability': 0.714,
#      'energy': 0.343,
#      'key': 10,
#      'loudness': -7.641,
#      'mode': 1,
#      'speechiness': 0.38,
#      'acousticness': 0.723,
#      'instrumentalness': 5.48e-06,
#      'liveness': 0.102,
#      'valence': 0.372,
#      'tempo': 72.348,
#      'type': 'audio_features',
#      'id': '2VQc9orzwE6a5qFfy54P6e',
#      'uri': 'spotify:track:2VQc9orzwE6a5qFfy54P6e',
#      'track_href': 'https://api.spotify.com/v1/tracks/2VQc9orzwE6a5qFfy54P6e',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2VQc9orzwE6a5qFfy54P6e',
#      'duration_ms': 221940,
#      'time_signature': 4}]},
#   {'track': 'Love poem',
#    'artist': 'IU',
#    'album': 'Love poem',
#    'id': '7HrE6HtYNBbGqp5GmHbFV0',
#    'track_url': 'https://open.spotify.com/embed/track/7HrE6HtYNBbGqp5GmHbFV0',
#    'audio_features': [{'danceability': 0.404,
#      'energy': 0.467,
#      'key': 11,
#      'loudness': -5.276,
#      'mode': 1,
#      'speechiness': 0.0413,
#      'acousticness': 0.74,
#      'instrumentalness': 0,
#      'liveness': 0.106,
#      'valence': 0.273,
#      'tempo': 119.994,
#      'type': 'audio_features',
#      'id': '7HrE6HtYNBbGqp5GmHbFV0',
#      'uri': 'spotify:track:7HrE6HtYNBbGqp5GmHbFV0',
#      'track_href': 'https://api.spotify.com/v1/tracks/7HrE6HtYNBbGqp5GmHbFV0',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7HrE6HtYNBbGqp5GmHbFV0',
#      'duration_ms': 258239,
#      'time_signature': 4}]},
#   {'track': 'Popo (How deep is our love?)',
#    'artist': 'Yerin Baek',
#    'album': 'Every letter I sent you.',
#    'id': '5XAJzwa0B2Hf8Rb1q0rowN',
#    'track_url': 'https://open.spotify.com/embed/track/5XAJzwa0B2Hf8Rb1q0rowN',
#    'audio_features': [{'danceability': 0.619,
#      'energy': 0.47,
#      'key': 0,
#      'loudness': -7.095,
#      'mode': 0,
#      'speechiness': 0.0479,
#      'acousticness': 0.509,
#      'instrumentalness': 0.00225,
#      'liveness': 0.0681,
#      'valence': 0.716,
#      'tempo': 84.939,
#      'type': 'audio_features',
#      'id': '5XAJzwa0B2Hf8Rb1q0rowN',
#      'uri': 'spotify:track:5XAJzwa0B2Hf8Rb1q0rowN',
#      'track_href': 'https://api.spotify.com/v1/tracks/5XAJzwa0B2Hf8Rb1q0rowN',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XAJzwa0B2Hf8Rb1q0rowN',
#      'duration_ms': 271216,
#      'time_signature': 4}]},
#   {'track': '비밀의 화원 [Bimilui Hwawon] : Secret Garden',
#    'artist': 'IU',
#    'album': '꽃갈피 둘 [Kkot-Galpi #2] : A flower bookmark',
#    'id': '5F6nAnNIsRk9QbPOx9t11B',
#    'track_url': 'https://open.spotify.com/embed/track/5F6nAnNIsRk9QbPOx9t11B',
#    'audio_features': [{'danceability': 0.482,
#      'energy': 0.387,
#      'key': 2,
#      'loudness': -7.486,
#      'mode': 1,
#      'speechiness': 0.0472,
#      'acousticness': 0.825,
#      'instrumentalness': 0,
#      'liveness': 0.138,
#      'valence': 0.258,
#      'tempo': 115.051,
#      'type': 'audio_features',
#      'id': '5F6nAnNIsRk9QbPOx9t11B',
#      'uri': 'spotify:track:5F6nAnNIsRk9QbPOx9t11B',
#      'track_href': 'https://api.spotify.com/v1/tracks/5F6nAnNIsRk9QbPOx9t11B',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5F6nAnNIsRk9QbPOx9t11B',
#      'duration_ms': 224791,
#      'time_signature': 4}]},
#   {'track': 'lit(var)',
#    'artist': 'Kensuke Ushio',
#    'album': 'A Shape of Light "A Silent Voice the Movie" Original Soundtrack',
#    'id': '6bTCdqB1PN5J93hiiZvQzW',
#    'track_url': 'https://open.spotify.com/embed/track/6bTCdqB1PN5J93hiiZvQzW',
#    'audio_features': [{'danceability': 0.329,
#      'energy': 0.258,
#      'key': 1,
#      'loudness': -16.147,
#      'mode': 0,
#      'speechiness': 0.0615,
#      'acousticness': 0.943,
#      'instrumentalness': 0.934,
#      'liveness': 0.105,
#      'valence': 0.0338,
#      'tempo': 95.328,
#      'type': 'audio_features',
#      'id': '6bTCdqB1PN5J93hiiZvQzW',
#      'uri': 'spotify:track:6bTCdqB1PN5J93hiiZvQzW',
#      'track_href': 'https://api.spotify.com/v1/tracks/6bTCdqB1PN5J93hiiZvQzW',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6bTCdqB1PN5J93hiiZvQzW',
#      'duration_ms': 134787,
#      'time_signature': 5}]},
#   {'track': 'I Know A Place',
#    'artist': 'MUNA',
#    'album': 'About U',
#    'id': '0bPSRn4crnh5f1JhELPlyL',
#    'track_url': 'https://open.spotify.com/embed/track/0bPSRn4crnh5f1JhELPlyL',
#    'audio_features': [{'danceability': 0.685,
#      'energy': 0.9,
#      'key': 5,
#      'loudness': -4.626,
#      'mode': 0,
#      'speechiness': 0.151,
#      'acousticness': 0.137,
#      'instrumentalness': 0,
#      'liveness': 0.2,
#      'valence': 0.779,
#      'tempo': 111.991,
#      'type': 'audio_features',
#      'id': '0bPSRn4crnh5f1JhELPlyL',
#      'uri': 'spotify:track:0bPSRn4crnh5f1JhELPlyL',
#      'track_href': 'https://api.spotify.com/v1/tracks/0bPSRn4crnh5f1JhELPlyL',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0bPSRn4crnh5f1JhELPlyL',
#      'duration_ms': 272813,
#      'time_signature': 4}]},
#   {'track': 'Implicit Demand For Proof',
#    'artist': 'Twenty One Pilots',
#    'album': 'Twenty One Pilots',
#    'id': '3UaFnnUo80mv431WHEzaj9',
#    'track_url': 'https://open.spotify.com/embed/track/3UaFnnUo80mv431WHEzaj9',
#    'audio_features': [{'danceability': 0.495,
#      'energy': 0.262,
#      'key': 9,
#      'loudness': -10.572,
#      'mode': 0,
#      'speechiness': 0.0292,
#      'acousticness': 0.635,
#      'instrumentalness': 0.00486,
#      'liveness': 0.104,
#      'valence': 0.287,
#      'tempo': 159.986,
#      'type': 'audio_features',
#      'id': '3UaFnnUo80mv431WHEzaj9',
#      'uri': 'spotify:track:3UaFnnUo80mv431WHEzaj9',
#      'track_href': 'https://api.spotify.com/v1/tracks/3UaFnnUo80mv431WHEzaj9',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3UaFnnUo80mv431WHEzaj9',
#      'duration_ms': 291933,
#      'time_signature': 3}]},
#   {'track': 'Heavydirtysoul',
#    'artist': 'Twenty One Pilots',
#    'album': 'Blurryface',
#    'id': '7i9763l5SSfOnqZ35VOcfy',
#    'track_url': 'https://open.spotify.com/embed/track/7i9763l5SSfOnqZ35VOcfy',
#    'audio_features': [{'danceability': 0.613,
#      'energy': 0.873,
#      'key': 7,
#      'loudness': -6.376,
#      'mode': 0,
#      'speechiness': 0.0449,
#      'acousticness': 0.00397,
#      'instrumentalness': 0.00111,
#      'liveness': 0.367,
#      'valence': 0.392,
#      'tempo': 129.989,
#      'type': 'audio_features',
#      'id': '7i9763l5SSfOnqZ35VOcfy',
#      'uri': 'spotify:track:7i9763l5SSfOnqZ35VOcfy',
#      'track_href': 'https://api.spotify.com/v1/tracks/7i9763l5SSfOnqZ35VOcfy',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7i9763l5SSfOnqZ35VOcfy',
#      'duration_ms': 234813,
#      'time_signature': 4}]},
#   {'track': 'Date',
#    'artist': 'RADWIMPS',
#    'album': 'Your Name.',
#    'id': '7A7lxMWZI2Uow7WqWjWGcM',
#    'track_url': 'https://open.spotify.com/embed/track/7A7lxMWZI2Uow7WqWjWGcM',
#    'audio_features': [{'danceability': 0.673,
#      'energy': 0.119,
#      'key': 5,
#      'loudness': -20.274,
#      'mode': 1,
#      'speechiness': 0.0656,
#      'acousticness': 0.985,
#      'instrumentalness': 0.73,
#      'liveness': 0.114,
#      'valence': 0.478,
#      'tempo': 123.87,
#      'type': 'audio_features',
#      'id': '7A7lxMWZI2Uow7WqWjWGcM',
#      'uri': 'spotify:track:7A7lxMWZI2Uow7WqWjWGcM',
#      'track_href': 'https://api.spotify.com/v1/tracks/7A7lxMWZI2Uow7WqWjWGcM',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7A7lxMWZI2Uow7WqWjWGcM',
#      'duration_ms': 245907,
#      'time_signature': 4}]},
#   {'track': 'Flesh without Blood',
#    'artist': 'Grimes',
#    'album': 'Art Angels',
#    'id': '4ZcGbQ5dOKX6rJk4yvza9R',
#    'track_url': 'https://open.spotify.com/embed/track/4ZcGbQ5dOKX6rJk4yvza9R',
#    'audio_features': [{'danceability': 0.481,
#      'energy': 0.965,
#      'key': 8,
#      'loudness': -2.993,
#      'mode': 1,
#      'speechiness': 0.0875,
#      'acousticness': 0.000904,
#      'instrumentalness': 0.000727,
#      'liveness': 0.476,
#      'valence': 0.66,
#      'tempo': 155.938,
#      'type': 'audio_features',
#      'id': '4ZcGbQ5dOKX6rJk4yvza9R',
#      'uri': 'spotify:track:4ZcGbQ5dOKX6rJk4yvza9R',
#      'track_href': 'https://api.spotify.com/v1/tracks/4ZcGbQ5dOKX6rJk4yvza9R',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ZcGbQ5dOKX6rJk4yvza9R',
#      'duration_ms': 264524,
#      'time_signature': 4}]},
#   {'track': 'The Taste of Ink',
#    'artist': 'The Used',
#    'album': 'The Used',
#    'id': '5jZ1Z2GFTf2gwmFc3qiUxs',
#    'track_url': 'https://open.spotify.com/embed/track/5jZ1Z2GFTf2gwmFc3qiUxs',
#    'audio_features': [{'danceability': 0.541,
#      'energy': 0.904,
#      'key': 7,
#      'loudness': -3.001,
#      'mode': 1,
#      'speechiness': 0.0435,
#      'acousticness': 0.00143,
#      'instrumentalness': 0,
#      'liveness': 0.193,
#      'valence': 0.541,
#      'tempo': 98.122,
#      'type': 'audio_features',
#      'id': '5jZ1Z2GFTf2gwmFc3qiUxs',
#      'uri': 'spotify:track:5jZ1Z2GFTf2gwmFc3qiUxs',
#      'track_href': 'https://api.spotify.com/v1/tracks/5jZ1Z2GFTf2gwmFc3qiUxs',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5jZ1Z2GFTf2gwmFc3qiUxs',
#      'duration_ms': 208693,
#      'time_signature': 4}]},
#   {'track': 'Lullaby',
#    'artist': 'IU',
#    'album': 'Love poem',
#    'id': '7BUtoP9NXEe7MgWvIG2KGE',
#    'track_url': 'https://open.spotify.com/embed/track/7BUtoP9NXEe7MgWvIG2KGE',
#    'audio_features': [{'danceability': 0.473,
#      'energy': 0.297,
#      'key': 3,
#      'loudness': -6.706,
#      'mode': 1,
#      'speechiness': 0.0339,
#      'acousticness': 0.889,
#      'instrumentalness': 0,
#      'liveness': 0.133,
#      'valence': 0.292,
#      'tempo': 129.083,
#      'type': 'audio_features',
#      'id': '7BUtoP9NXEe7MgWvIG2KGE',
#      'uri': 'spotify:track:7BUtoP9NXEe7MgWvIG2KGE',
#      'track_href': 'https://api.spotify.com/v1/tracks/7BUtoP9NXEe7MgWvIG2KGE',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BUtoP9NXEe7MgWvIG2KGE',
#      'duration_ms': 261720,
#      'time_signature': 4}]},
#   {'track': 'Dream lantern',
#    'artist': 'RADWIMPS',
#    'album': 'Your Name.',
#    'id': '5mEqD00bdFcsiVd0MfvEeF',
#    'track_url': 'https://open.spotify.com/embed/track/5mEqD00bdFcsiVd0MfvEeF',
#    'audio_features': [{'danceability': 0.206,
#      'energy': 0.871,
#      'key': 8,
#      'loudness': -5.751,
#      'mode': 1,
#      'speechiness': 0.419,
#      'acousticness': 0.0316,
#      'instrumentalness': 6.55e-05,
#      'liveness': 0.0596,
#      'valence': 0.125,
#      'tempo': 175.6,
#      'type': 'audio_features',
#      'id': '5mEqD00bdFcsiVd0MfvEeF',
#      'uri': 'spotify:track:5mEqD00bdFcsiVd0MfvEeF',
#      'track_href': 'https://api.spotify.com/v1/tracks/5mEqD00bdFcsiVd0MfvEeF',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mEqD00bdFcsiVd0MfvEeF',
#      'duration_ms': 131667,
#      'time_signature': 3}]},
#   {'track': 'Happy Day',
#    'artist': '1set',
#    'album': 'Sisters-in-law, Pt. 3 (Original Soundtrack)',
#    'id': '6XWJnONhIytzRvc1PXB6m7',
#    'track_url': 'https://open.spotify.com/embed/track/6XWJnONhIytzRvc1PXB6m7',
#    'audio_features': [{'danceability': 0.656,
#      'energy': 0.631,
#      'key': 0,
#      'loudness': -4.268,
#      'mode': 1,
#      'speechiness': 0.0899,
#      'acousticness': 0.554,
#      'instrumentalness': 0,
#      'liveness': 0.198,
#      'valence': 0.548,
#      'tempo': 99.215,
#      'type': 'audio_features',
#      'id': '6XWJnONhIytzRvc1PXB6m7',
#      'uri': 'spotify:track:6XWJnONhIytzRvc1PXB6m7',
#      'track_href': 'https://api.spotify.com/v1/tracks/6XWJnONhIytzRvc1PXB6m7',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6XWJnONhIytzRvc1PXB6m7',
#      'duration_ms': 166375,
#      'time_signature': 4}]},
#   {'track': 'Black Out',
#    'artist': 'IU',
#    'album': 'Palette',
#    'id': '1sUOFqmIU38dQCA13aVKBL',
#    'track_url': 'https://open.spotify.com/embed/track/1sUOFqmIU38dQCA13aVKBL',
#    'audio_features': [{'danceability': 0.684,
#      'energy': 0.801,
#      'key': 8,
#      'loudness': -4.063,
#      'mode': 1,
#      'speechiness': 0.0651,
#      'acousticness': 0.166,
#      'instrumentalness': 2.37e-06,
#      'liveness': 0.0243,
#      'valence': 0.778,
#      'tempo': 98.042,
#      'type': 'audio_features',
#      'id': '1sUOFqmIU38dQCA13aVKBL',
#      'uri': 'spotify:track:1sUOFqmIU38dQCA13aVKBL',
#      'track_href': 'https://api.spotify.com/v1/tracks/1sUOFqmIU38dQCA13aVKBL',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1sUOFqmIU38dQCA13aVKBL',
#      'duration_ms': 227701,
#      'time_signature': 4}]},
#   {'track': 'Saw You In A Dream',
#    'artist': 'The Japanese House',
#    'album': 'Saw You In A Dream',
#    'id': '0U3u0HdRQjD8mAMYBak4Ok',
#    'track_url': 'https://open.spotify.com/embed/track/0U3u0HdRQjD8mAMYBak4Ok',
#    'audio_features': [{'danceability': 0.607,
#      'energy': 0.451,
#      'key': 4,
#      'loudness': -8.206,
#      'mode': 1,
#      'speechiness': 0.0286,
#      'acousticness': 0.0604,
#      'instrumentalness': 0,
#      'liveness': 0.19,
#      'valence': 0.676,
#      'tempo': 94.054,
#      'type': 'audio_features',
#      'id': '0U3u0HdRQjD8mAMYBak4Ok',
#      'uri': 'spotify:track:0U3u0HdRQjD8mAMYBak4Ok',
#      'track_href': 'https://api.spotify.com/v1/tracks/0U3u0HdRQjD8mAMYBak4Ok',
#      'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0U3u0HdRQjD8mAMYBak4Ok',
#      'duration_ms': 208280,
#      'time_signature': 4}]}],
#  'genres': ['k-pop',
#   'j-pop',
#   'j-rock',
#   'japanese emo',
#   'visual kei',
#   'k-pop',
#   'k-pop girl group',
#   'anime',
#   'anime rock',
#   'anime score',
#   'otacore',
#   'k-pop',
#   'k-pop girl group',
#   'modern rock',
#   'pop punk',
#   'art pop',
#   'electropop',
#   'indie pop',
#   'indie poptimism',
#   'indietronica',
#   'modern dream pop',
#   'vapor soul',
#   'japanese instrumental',
#   'otacore',
#   'scorecore',
#   'modern rock',
#   'rock',
#   'art pop',
#   'canadian electropop',
#   'chillwave',
#   'dance pop',
#   'electropop',
#   'escape room',
#   'grave wave',
#   'indie pop',
#   'indietronica',
#   'metropopolis',
#   'alternative dance',
#   'auckland indie',
#   'electropop',
#   'indie pop',
#   'indie poptimism',
#   'indie rock',
#   'indietronica',
#   'kiwi rock',
#   'metropopolis',
#   'modern rock',
#   'shimmer pop',
#   'electropop',
#   'indie pop',
#   'indie poptimism',
#   'metropopolis',
#   'neo-synthpop',
#   'shimmer pop',
#   'k-indie',
#   'k-pop',
#   'korean pop',
#   'anime rock',
#   'j-pixie',
#   'otacore',
#   'art pop',
#   'dance pop',
#   'electropop',
#   'indie electropop',
#   'indie pop',
#   'indie poptimism',
#   'la pop',
#   'metropopolis',
#   'pop',
#   'vapor soul',
#   'anti-folk',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'melancholia',
#   'omaha indie',
#   'stomp and holler',
#   'dreamo',
#   'indie rock',
#   'modern rock',
#   'alternative dance',
#   'art pop',
#   'brooklyn indie',
#   'chillwave',
#   'electropop',
#   'escape room',
#   'indie pop',
#   'metropopolis',
#   'neo-synthpop',
#   'shimmer pop',
#   'emo',
#   'pop punk',
#   'escape room',
#   'hyperpop',
#   'japanese electropop',
#   'alternative dance',
#   'canadian indie',
#   'canadian rock',
#   'dance-punk',
#   'electropop',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'metropopolis',
#   'modern rock',
#   'neo-synthpop',
#   'new rave',
#   'shimmer pop',
#   'art pop',
#   'chillwave',
#   'canadian ccm',
#   'christian alternative rock',
#   'christian music',
#   'christian punk',
#   'christian rock',
#   'indiecoustica',
#   'neo mellow',
#   'pop punk',
#   'pop rock',
#   'art pop',
#   'canadian electropop',
#   'chillwave',
#   'edmonton indie',
#   'electropop',
#   'grave wave',
#   'indietronica',
#   'metropopolis',
#   'shimmer pop',
#   'vapor soul',
#   'emo',
#   'neon pop punk',
#   'pop emo',
#   'pop punk',
#   'chicago rap',
#   'hip hop',
#   'rap',
#   'post-hardcore',
#   'screamo',
#   'alternative r&b',
#   'art pop',
#   'chillwave',
#   'electropop',
#   'escape room',
#   'indie soul',
#   'metropopolis',
#   'indie rock',
#   'modern alternative rock',
#   'modern rock',
#   'rock',
#   'k-pop',
#   'korean pop',
#   'emo',
#   'neon pop punk',
#   'piano rock',
#   'pop emo',
#   'pop punk',
#   'pop rock',
#   'k-indie',
#   'k-pop',
#   'korean r&b',
#   'alternative dance',
#   'chillwave',
#   'electropop',
#   'indie pop',
#   'indie rock',
#   'indietronica',
#   'metropopolis',
#   'modern rock',
#   'shimmer pop',
#   'vapor soul',
#   'anime score',
#   'eau claire indie',
#   'indie folk',
#   'melancholia',
#   'canadian indie',
#   'indie pop',
#   'indie poptimism',
#   'indie rock',
#   'lilith',
#   'metropopolis',
#   'permanent wave',
#   'pop rock',
#   'art pop',
#   'auckland indie',
#   'electropop',
#   'etherpop',
#   'indie electropop',
#   'indie pop',
#   'indie poptimism',
#   'indietronica',
#   'metropopolis',
#   'nz pop',
#   'pop',
#   'shimmer pop',
#   'tropical house',
#   'vapor soul',
#   'downtempo',
#   'dream pop',
#   'indietronica',
#   'indie pop',
#   'metropopolis',
#   'shimmer pop',
#   'stomp and holler',
#   'stomp and whittle',
#   'alternative r&b',
#   'art pop',
#   'dance pop',
#   'electropop',
#   'indie poptimism',
#   'pop',
#   'vapor soul',
#   'anime score',
#   'japanese soundtrack',
#   'otacore',
#   'metropopolis',
#   'modern rock',
#   'pop',
#   'pop rock',
#   'gauze pop',
#   'hopebeat',
#   'indie pop',
#   'indie poptimism',
#   'shimmer pop',
#   'uk pop',
#   'vapor soul',
#   'art pop',
#   'electropop',
#   'etherpop',
#   'indie folk',
#   'indie pop',
#   'indie rock',
#   'alt-idol',
#   'anime',
#   'anime rock',
#   'heavy alternative',
#   'idol rock',
#   'j-idol',
#   'j-pixie',
#   'j-pop',
#   'brooklyn indie',
#   'electropop',
#   'indie electropop',
#   'indie pop',
#   'indie poptimism',
#   'nyc pop',
#   'pop',
#   'vapor soul',
#   'art pop',
#   'dance pop',
#   'indie pop',
#   'metropopolis',
#   'pop',
#   'pop rock',
#   'rock',
#   'metropopolis',
#   'nottingham indie',
#   'brooklyn indie',
#   'indie rock',
#   'vapor soul',
#   'alternative dance',
#   'chillwave',
#   'electropop',
#   'indie pop',
#   'indie poptimism',
#   'indietronica',
#   'metropopolis',
#   'modern alternative rock',
#   'modern rock',
#   'neo-synthpop',
#   'nyc pop',
#   'shimmer pop',
#   'vapor soul'],
#  'average_artist_popularity': 65}

# %%
with open('../test/user_stats.json', 'w') as json_file:
    json.dump(user_stats, json_file)
