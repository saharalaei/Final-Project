# %%
import matplotlib.pyplot as plt
import pandas as pd
import requests
import spotipy
import scipy.stats as st
from scipy.optimize import curve_fit
import numpy as np

#from config import credentials
# Import API key
#from config import api_key
#from config import token

# %%
user_id='me'
kind='artists' #tracks
limit=50
token='BQBHPjmMeodVhfryjBulQLZdjmi6k4Z1rqoT1KGDxkBHv70r-E_oE_odmIBYCOgPJGc2xXR-_JoqoalX2MV_5HlmWw-46cQ5T2L1Le24foEz5plF2Z1k93Y5MXRghm4vDivQg9e24cjsMB_2nol5fySRa9rziSV2FeGdebUYXPEN-y1dIxn_54vDALUDSF8TnkOcoZtdSjUjNbleKzRp6GG3N5duisH6xsgE9EVLZXAiZz4pgeqFwmnoidilVEhnnS4HoF_3gyq7kjPC'

params={'time_range':'long_term','limit' : limit}
headers={"Accept": "application/json","Content-Type": "application/json","Authorization": 
         (f"Bearer {token}")}

#medium_term, short term

base_url=f'https://api.spotify.com/v1/{user_id}/top/{kind}?'#{api_key}'    #{timeframe}/{api_key}

# %%
#https://api.spotify.com/v1/me/top/artists?time_range=long_term&limit=20

# %%
url = https://api.spotify.com/v1/me

# %%
user_data = requests.get(base_url,headers = headers,params=params).json()

artists=[]
genres=[]
popularity=[]
for i in range(limit):

    artists.append(user_data['items'][i]['name'])
    genres.append(user_data['items'][i]['genres'])
    popularity.append(user_data['items'][i]['popularity'])

# %%
user_data['items'][0]['genres']
# Out:
# ['k-pop']

# %%
top50_df=pd.DataFrame({'artist':artists,
                       'genres':genres,
                       'popularity':popularity})
top50_df
# Out:
#                   artist                                             genres  \
# 0                     IU                                            [k-pop]
# 1               RADWIMPS          [j-pop, j-rock, japanese emo, visual kei]
# 2                  TWICE                          [k-pop, k-pop girl group]
# 3                 EGOIST          [anime, anime rock, anime score, otacore]
# 4                GFRIEND                          [k-pop, k-pop girl group]
# 5           All Time Low             [modern rock, pop punk, post-teen pop]
# 6     The Japanese House  [art pop, electropop, indie pop, indie poptimi...
# 7             daigoro789        [japanese instrumental, otacore, scorecore]
# 8      Twenty One Pilots                                [modern rock, rock]
# 9                 Grimes  [art pop, canadian electropop, chillwave, danc...
# 10  The Naked And Famous  [alternative dance, auckland indie, electropop...
# 11              CHVRCHES  [electropop, indie pop, indie poptimism, metro...
# 12            Yerin Baek                       [k-indie, k-pop, korean pop]
# 13                  LiSA                     [anime rock, j-pixie, otacore]
# 14                  MUNA  [art pop, dance pop, electropop, indie electro...
# 15           Bright Eyes  [indie folk, indie pop, indie rock, melancholi...
# 16  Manchester Orchestra                  [dreamo, indie rock, modern rock]
# 17             Chairlift  [alternative dance, art pop, brooklyn indie, c...
# 18    Taking Back Sunday                                    [emo, pop punk]
# 19      Kero Kero Bonito       [escape room, hyperpop, japanese electropop]
# 20                Metric  [alternative dance, canadian indie, canadian r...
# 21        Mr Twin Sister                               [art pop, chillwave]
# 22             Relient K  [canadian ccm, christian alternative rock, chr...
# 23           Purity Ring  [art pop, canadian electropop, chillwave, edmo...
# 24         Mayday Parade            [emo, neon pop punk, pop emo, pop punk]
# 25            Kanye West                                 [chicago rap, rap]
# 26              The Used                      [emo, post-hardcore, screamo]
# 27          Blood Orange  [alternative r&b, art pop, chillwave, electrop...
# 28            Wolf Alice  [indie rock, modern alternative rock, modern r...
# 29                  BOL4                                [k-pop, korean pop]
# 30   Something Corporate  [emo, neon pop punk, piano rock, pop emo, pop ...
# 31                 SURAN                       [k-indie, k-pop, korean r&b]
# 32            Phantogram  [alternative dance, chillwave, electropop, ind...
# 33                  藤澤慶昌                                      [anime score]
# 34              Bon Iver        [eau claire indie, indie folk, melancholia]
# 35        Tegan and Sara  [canadian indie, indie pop, indie poptimism, i...
# 36                Broods  [art pop, auckland indie, electropop, etherpop...
# 37                The xx               [downtempo, dream pop, indietronica]
# 38           Kishi Bashi  [indie pop, metropopolis, shimmer pop, stomp a...
# 39                 BANKS  [alternative r&b, art pop, dance pop, electrop...
# 40         Kensuke Ushio        [anime score, japanese soundtrack, otacore]
# 41              Bastille         [metropopolis, modern rock, pop, pop rock]
# 42        Fickle Friends  [gauze pop, hopebeat, indie electropop, indie ...
# 43           Sylvan Esso  [art pop, electropop, etherpop, indie folk, in...
# 44          SILENT SIREN  [alt-idol, anime, anime rock, heavy alternativ...
# 45                   Wet  [brooklyn indie, electropop, indie electropop,...
# 46                  HAIM  [art pop, dance pop, indie pop, metropopolis, ...
# 47        London Grammar                   [metropopolis, nottingham indie]
# 48             St. Lucia  [alternative dance, chillwave, electropop, ind...
# 49              Paramore         [candy pop, emo, pixie, pop emo, pop punk]
#
#     popularity
# 0           77
# 1           75
# 2           82
# 3           58
# 4           67
# 5           75
# 6           67
# 7           62
# 8           86
# 9           73
# 10          63
# 11          72
# 12          63
# 13          74
# 14          61
# 15          66
# 16          62
# 17          48
# 18          65
# 19          63
# 20          63
# 21          50
# 22          61
# 23          60
# 24          68
# 25          91
# 26          68
# 27          69
# 28          60
# 29          69
# 30          50
# 31          61
# 32          63
# 33          37
# 34          81
# 35          63
# 36          63
# 37          72
# 38          55
# 39          67
# 40          61
# 41          81
# 42          51
# 43          69
# 44          51
# 45          59
# 46          72
# 47          72
# 48          57
# 49          80

# %%
#top50_df['genres'].value_counts
genres = pd.Series([x for item in top50_df.genres for x in item]).value_counts().reset_index()
genres=genres.rename(columns={'index':'genre',0:'count'})
genres.head(20)
#genre_list = genres['genre'].tolist()
#genre_list = sorted(genre_list)
#genre_list
#len(genre_list)
# Out:
#                 genre  count
# 0           indie pop     17
# 1        metropopolis     16
# 2          electropop     15
# 3             art pop     11
# 4     indie poptimism     10
# 5         shimmer pop     10
# 6          vapor soul      9
# 7         modern rock      9
# 8        indietronica      9
# 9          indie rock      8
# 10          chillwave      7
# 11                pop      6
# 12              k-pop      6
# 13           pop rock      6
# 14           pop punk      6
# 15                emo      6
# 16  alternative dance      5
# 17   indie electropop      4
# 18           new rave      4
# 19          dance pop      4

# %%
#use these columns for parameters for the pie chart
counts = top_genres['count']
genres = top_genres['genre']
#explode = 

#found a bunch of colors here
#https://matplotlib.org/3.1.0/gallery/color/named_colors.html
#colors = ["magenta","deepskyblue"]
#contruct plot
plt.figure(figsize = (5,5))
plt.pie(counts,labels=genres, autopct="%.1f%%", )
#plt.title("Mice Gender Distribution")
plt.axis("equal")
plt.show()

# %%
popularity_df=top50_df.sort_values('popularity',ascending=False)
popularity_df
# Out:
#                   artist                                             genres  \
# 25            Kanye West                                 [chicago rap, rap]
# 8      Twenty One Pilots                                [modern rock, rock]
# 2                  TWICE                          [k-pop, k-pop girl group]
# 41              Bastille         [metropopolis, modern rock, pop, pop rock]
# 34              Bon Iver        [eau claire indie, indie folk, melancholia]
# 49              Paramore         [candy pop, emo, pixie, pop emo, pop punk]
# 0                     IU                                            [k-pop]
# 5           All Time Low             [modern rock, pop punk, post-teen pop]
# 1               RADWIMPS          [j-pop, j-rock, japanese emo, visual kei]
# 13                  LiSA                     [anime rock, j-pixie, otacore]
# 9                 Grimes  [art pop, canadian electropop, chillwave, danc...
# 47        London Grammar                   [metropopolis, nottingham indie]
# 11              CHVRCHES  [electropop, indie pop, indie poptimism, metro...
# 46                  HAIM  [art pop, dance pop, indie pop, metropopolis, ...
# 37                The xx               [downtempo, dream pop, indietronica]
# 43           Sylvan Esso  [art pop, electropop, etherpop, indie folk, in...
# 29                  BOL4                                [k-pop, korean pop]
# 27          Blood Orange  [alternative r&b, art pop, chillwave, electrop...
# 24         Mayday Parade            [emo, neon pop punk, pop emo, pop punk]
# 26              The Used                      [emo, post-hardcore, screamo]
# 39                 BANKS  [alternative r&b, art pop, dance pop, electrop...
# 4                GFRIEND                          [k-pop, k-pop girl group]
# 6     The Japanese House  [art pop, electropop, indie pop, indie poptimi...
# 15           Bright Eyes  [indie folk, indie pop, indie rock, melancholi...
# 18    Taking Back Sunday                                    [emo, pop punk]
# 36                Broods  [art pop, auckland indie, electropop, etherpop...
# 10  The Naked And Famous  [alternative dance, auckland indie, electropop...
# 20                Metric  [alternative dance, canadian indie, canadian r...
# 19      Kero Kero Bonito       [escape room, hyperpop, japanese electropop]
# 12            Yerin Baek                       [k-indie, k-pop, korean pop]
# 32            Phantogram  [alternative dance, chillwave, electropop, ind...
# 35        Tegan and Sara  [canadian indie, indie pop, indie poptimism, i...
# 7             daigoro789        [japanese instrumental, otacore, scorecore]
# 16  Manchester Orchestra                  [dreamo, indie rock, modern rock]
# 31                 SURAN                       [k-indie, k-pop, korean r&b]
# 14                  MUNA  [art pop, dance pop, electropop, indie electro...
# 40         Kensuke Ushio        [anime score, japanese soundtrack, otacore]
# 22             Relient K  [canadian ccm, christian alternative rock, chr...
# 23           Purity Ring  [art pop, canadian electropop, chillwave, edmo...
# 28            Wolf Alice  [indie rock, modern alternative rock, modern r...
# 45                   Wet  [brooklyn indie, electropop, indie electropop,...
# 3                 EGOIST          [anime, anime rock, anime score, otacore]
# 48             St. Lucia  [alternative dance, chillwave, electropop, ind...
# 38           Kishi Bashi  [indie pop, metropopolis, shimmer pop, stomp a...
# 42        Fickle Friends  [gauze pop, hopebeat, indie electropop, indie ...
# 44          SILENT SIREN  [alt-idol, anime, anime rock, heavy alternativ...
# 30   Something Corporate  [emo, neon pop punk, piano rock, pop emo, pop ...
# 21        Mr Twin Sister                               [art pop, chillwave]
# 17             Chairlift  [alternative dance, art pop, brooklyn indie, c...
# 33                  藤澤慶昌                                      [anime score]
#
#     popularity
# 25          91
# 8           86
# 2           82
# 41          81
# 34          81
# 49          80
# 0           77
# 5           75
# 1           75
# 13          74
# 9           73
# 47          72
# 11          72
# 46          72
# 37          72
# 43          69
# 29          69
# 27          69
# 24          68
# 26          68
# 39          67
# 4           67
# 6           67
# 15          66
# 18          65
# 36          63
# 10          63
# 20          63
# 19          63
# 12          63
# 32          63
# 35          63
# 7           62
# 16          62
# 31          61
# 14          61
# 40          61
# 22          61
# 23          60
# 28          60
# 45          59
# 3           58
# 48          57
# 38          55
# 42          51
# 44          51
# 30          50
# 21          50
# 17          48
# 33          37

# %%
mean_pop=popularity_df.mean()
print(popularity_df.mean())
# Out:
# popularity    65.66
# dtype: float64

# %%
monthly_listen=[31136355,19892244,5786789,19696892,8810802,4920540,6070574,2326642,4342067,7287210,2764446,2604646,
                4348878,4560359,2807877,1711729,2132838,2207593,1977451,1904265,999429,1423244,1654735,1925133,
               1445701,945814,1793936,1461294,1458824,820964,1734413,855722,783786,1184485,559604,928138,1055185,
               853462,1420310,1021964,436136,869287,896391,678255,307237,304716,374888,106790,337555,12476]

# %%
len(monthly_listen)
# Out:
# 50

# %%
poppy=popularity_df['popularity'].tolist()

pops=[97,95,91,95,84,89,89,73,83,87,89,91,86,78,86]
listens=[60696365,55170241,41987269,48867520,21692661,21024536,21487306,7642605,1704122,24823631,
        19651875,35018530,15602696,7057663,28074532]

poppy=poppy+pops
monthly_listen=monthly_listen+listens

x_axis=poppy
y_axis=monthly_listen
len(y_axis)
# Out:
# 65

# %%
#https://open.spotify.com/artist/6S2OmqARrzebs0tKUEyXyp?si=NHujpOOmS_i08KhJARSZEg

# %%
def exponential(x, a, b):
    return a*np.exp(b*x)

# %%
pars, cov = curve_fit(f=exponential, xdata=x_axis, ydata=y_axis, p0=[0, 0], bounds=(-np.inf, np.inf))

# %%
x1=np.arange(min(poppy),max(poppy)+1,1)
line_1 = pars[0]*np.exp(pars[1]*x1)

# %%
listeners=pars[0]*np.exp(pars[1]*mean_pop)
int(round(listeners,0))
# Out:
# 1828532

# %%
plt.figure(figsize=(10,7))
plt.yticks(np.arange(0,80000000,5000000))
plt.scatter(x_axis,y_axis)
plt.ylabel('Monthly Listeners\n')
plt.xlabel('\nPopularity')
ax = plt.gca()
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

plt.plot(mean_pop,listeners,markerfacecolor='red',marker="o",markersize=10)
plt.plot(x1, line_1, linestyle='--', linewidth=1, color='black')
plt.show()

# %%
# Out:
# 1769183

# %%
#genres['genre'] = genres['genre'].replace({'korean pop': 'k-pop',
#                                           'k-pop girl group':'k-pop',
#                                           'anime score':'anime',
#                                           'anime rock':'anime'})
top_genres=genres.iloc[:30,:]
#genres['count']

# %%
artist_list = [i for i in top50_df['artist']]

# %%
artist_list
# Out:
# ['IU',
#  'RADWIMPS',
#  'TWICE',
#  'EGOIST',
#  'GFRIEND',
#  'All Time Low',
#  'The Japanese House',
#  'daigoro789',
#  'Twenty One Pilots',
#  'Grimes',
#  'The Naked And Famous',
#  'CHVRCHES',
#  'Yerin Baek',
#  'LiSA',
#  'MUNA',
#  'Bright Eyes',
#  'Manchester Orchestra',
#  'Chairlift',
#  'Taking Back Sunday',
#  'Kero Kero Bonito',
#  'Metric',
#  'Mr Twin Sister',
#  'Relient K',
#  'Purity Ring',
#  'Mayday Parade',
#  'Kanye West',
#  'The Used',
#  'Blood Orange',
#  'Wolf Alice',
#  'BOL4',
#  'Something Corporate',
#  'SURAN',
#  'Phantogram',
#  '藤澤慶昌',
#  'Bon Iver',
#  'Tegan and Sara',
#  'Broods',
#  'The xx',
#  'Kishi Bashi',
#  'BANKS',
#  'Kensuke Ushio',
#  'Bastille',
#  'Fickle Friends',
#  'Sylvan Esso',
#  'SILENT SIREN',
#  'Wet',
#  'HAIM',
#  'London Grammar',
#  'St. Lucia',
#  'Paramore']

# %%
genres = [i for i in top50_df['genres']]

# %%
genres_complete = []
for i in genres:
    for a in i:
        genres_complete.append(a)
